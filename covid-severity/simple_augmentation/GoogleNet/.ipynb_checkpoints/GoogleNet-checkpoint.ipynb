# %% [markdown]
# ## **Chest X-ray classification between Covid, pneumonia, normal using GoogleNet**
#
# + **About**:
#     + This notebook contains code to run experiments for paper: Covid-19 Chest X-ray classification and severity assessment using Convolutional and Transformer Neural Networks
#
# + **Datasets**:
#     + The COVID CXR dataset
#     + The Chest Xray Pneumonia dataset
#
#
# + **Classes**:
#     + Normal
#     + Pneumonia
#     + Covid_19
#
# + **Architecture**:
#     + GoogLeNet

# %%
import os
import cv2
import platform
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from IPython.display import clear_output

os.environ['PYTHONHASHSEED'] = '73'

seed = 73
random.seed(seed)
np.random.seed(seed)

print(platform.platform())
# %matplotlib inline
# Out:
# Windows-10-10.0.19043-SP0

# %%
three_classes_covid_xray_balanced = "/Users/MCSP_Lab/Desktop/covidx-dataset/covidx-cxr2/datasets/covid_cxr_dataset/train_covidx9a_9449/train"

# %%
print('> train_covidx9a_balance_5555 dir:', os.listdir(three_classes_covid_xray_balanced))
# Out:
# > train_covidx9a_balance_5555 dir: ['covid-19', 'normal', 'pneumonia']

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### Read train_df

# %%
from tqdm import tqdm

train_image_dir = three_classes_covid_xray_balanced 
img_map = []

def prepareData(Dir, strat):
    cats = ["normal","pneumonia", "covid-19"]
    for category in cats:
        path = os.path.join(Dir,category)
        class_num = cats.index(category)
        
        for img in tqdm(os.listdir(path)):
            img_path = os.path.join(path,img)
            img_map.append({'path': img_path, 'label': category})

prepareData(train_image_dir,'train')
img_map_covidx9a = pd.DataFrame(img_map).sample(frac = 1, random_state=seed)
# Out:
# 100%|██████████| 9668/9668 [00:00<00:00, 311850.40it/s]
# 100%|██████████| 9828/9828 [00:00<00:00, 378193.88it/s]
# 100%|██████████| 9484/9484 [00:00<00:00, 364344.60it/s]

# %%
img_map_covidx9a.head()
# Out:
#                                                     path      label
# 6129   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...     normal
# 7917   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...     normal
# 13946  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  pneumonia
# 19830  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...   covid-19
# 5445   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...     normal

# %% [markdown]
# ### Read test_df

# %%
from tqdm import tqdm

test_image_dir = "/Users/MCSP_Lab/Desktop/covidx-dataset/covidx-cxr2/datasets/covid_cxr_dataset/test_covidx9a/" 

img_map = []

def prepareData(Dir, strat):
    cats = ["normal","pneumonia", "COVID-19"]
    for category in cats:
        path = os.path.join(Dir,category)
        class_num = cats.index(category)
        
        for img in tqdm(os.listdir(path)):
            img_path = os.path.join(path,img)
            img_map.append({'path': img_path, 'label': category})

prepareData(test_image_dir,'train')
test_img_map_covidx9a = pd.DataFrame(img_map).sample(frac = 1, random_state=seed)
# Out:
# 100%|██████████| 101/101 [00:00<?, ?it/s]
# 100%|██████████| 101/101 [00:00<?, ?it/s]
# 100%|██████████| 201/201 [00:00<?, ?it/s]

# %% [markdown]
# ### Images Visualization

# %%
import matplotlib.pyplot as plt

def print_images(samples): 
    images = samples["path"].to_numpy()
    labels = samples['label'].to_numpy()
    
    fig=plt.figure(figsize=(20, 8))
    columns = 4
    rows = 1
    
    for i, image_path in enumerate(images):
        image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        
        fig.add_subplot(rows,columns,i + 1)
        title = '{}'.format(labels[i])
        
        Sample_image = cv2.resize(image, (224, 224), interpolation = cv2.INTER_CUBIC)
        
        plt.imshow(Sample_image, cmap='gray')
        plt.title(title)
        
    plt.show()
        
print_images(img_map_covidx9a[img_map_covidx9a['label']=="normal"].iloc[0:4])
print_images(img_map_covidx9a[img_map_covidx9a['label']=="pneumonia"].iloc[0:4])
print_images(img_map_covidx9a[img_map_covidx9a['label']=="covid-19"].iloc[0:4])

# %matplotlib inline

# %%
def getLabelCount(frame):
    label_count = pd.Series(frame['label'].values.ravel()).value_counts()
    n_classes = (label_count)
    return label_count

label_count = getLabelCount(img_map_covidx9a)
print(label_count)
# Out:
# pneumonia    9828
# normal       9668
# covid-19     9484
# dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

features = img_map_covidx9a['path'].to_numpy()
labels = img_map_covidx9a['label'].to_numpy()

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.2, random_state=73)

# %%
for train_index, val_index in stratified_sample.split(features, labels):
    X_train, val_X = features[train_index], features[val_index]
    y_train, val_y = labels[train_index], labels[val_index]
    
half_size = np.int(len(val_X))
X_val, y_val = val_X[0:half_size], val_y[0:half_size]
# Out:
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_27136/2451442638.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   half_size = np.int(len(val_X))

# %%
train_map = pd.DataFrame()
train_map['path'], train_map['label'] = X_train, y_train

# %%
val_map = pd.DataFrame()
val_map['path'], val_map['label'] = X_val, y_val

# %%
# data summary
print('> {} train size'.format(X_train.shape[0]))
print('> {} val size'.format(X_val.shape[0]))
# Out:
# > 23184 train size
# > 5796 val size

# %%
train_map.head()
# Out:
#                                                 path      label
# 0  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...   covid-19
# 1  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...   covid-19
# 2  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...     normal
# 3  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...     normal
# 4  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  pneumonia

# %% [markdown]
# ### Data Augmentation

# %%
import cv2
import time
import imageio
import imgaug.augmenters as iaa
import imgaug as ia
ia.seed(73)

ColorCh = 3
#IMG_SIZE = 224
IMG_SIZE = 224
input_shape=(IMG_SIZE, IMG_SIZE, ColorCh)

classes = ("COVID", "NORMAL","PNEUMONIA")
CATEGORIES = sorted(classes)

print('> Classes:',CATEGORIES)
# Out:
# > Classes: ['COVID', 'NORMAL', 'PNEUMONIA']

# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

datagen = ImageDataGenerator(rescale = 1./255, 
                             horizontal_flip=True,
                             brightness_range=[1.0,1.3],
                             rotation_range=15,
                             #zoom_range=0.2
                            )

# %%
batch_size = 8

def get_generator(frame_):
    generator = datagen.flow_from_dataframe(
                          dataframe=frame_,
                          x_col="path",
                          y_col="label",
                          batch_size=batch_size,
                          seed=seed,
                          shuffle=False,
                          class_mode="sparse",
                          color_mode="rgb",
                          save_format="jpeg",
                          target_size=(IMG_SIZE,IMG_SIZE)             
             )
    
    return generator

# %% [markdown]
# ### Get train_generator

# %%
train_df = train_map.sample(frac=1, random_state=seed)
train_generator = get_generator(train_df)

print('> label count for train set')
getLabelCount(train_df)
# Out:
# Found 23184 validated image filenames belonging to 3 classes.
# > label count for train set
# pneumonia    7862
# normal       7735
# covid-19     7587
# dtype: int64

# %%
val_df = val_map.sample(frac=1, random_state=seed)
val_generator = get_generator(val_df)

print('> label count for val set')
getLabelCount(val_df)
# Out:
# Found 5796 validated image filenames belonging to 3 classes.
# > label count for val set
# pneumonia    1966
# normal       1933
# covid-19     1897
# dtype: int64

# %%
test_generator = get_generator(test_img_map_covidx9a)

print('> label count for test set')
getLabelCount(test_img_map_covidx9a)
# Out:
# Found 400 validated image filenames belonging to 3 classes.
# > label count for test set
# C:\Users\MCSP_Lab\anaconda3\envs\python-3-9\lib\site-packages\keras_preprocessing\image\dataframe_iterator.py:279: UserWarning: Found 3 invalid image filename(s) in x_col="path". These filename(s) will be ignored.
#   warnings.warn(
# COVID-19     201
# normal       101
# pneumonia    101
# dtype: int64

# %%
print('> input shape:', input_shape)
# Out:
# > input shape: (224, 224, 3)

# %% [markdown]
# ## **Model Construction**

# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Add, add
from tensorflow.keras.layers import InputLayer, Input, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Activation, MaxPool2D, ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model, Sequential
from keras import regularizers

kernel_regularizer = regularizers.l2(0.0001)

final_activation = 'softmax'
entropy = 'sparse_categorical_crossentropy'
n_classes = len(CATEGORIES)
print('> {} classes'.format(n_classes))
# Out:
# > 3 classes

# %%
def FCLayers(baseModel):
    baseModel.trainable = True
    headModel = baseModel.output
    headModel = Dropout(0.5, seed=73)(headModel)
    headModel = Dense(n_classes, activation=final_activation)(headModel)
    
    model = Model(inputs = baseModel.input, outputs = headModel)
    return model

# %% [markdown]
# ### Build GoogleNet

# %%
from keras.layers.merge import concatenate

def Inception_block(input_layer, f1, f2, f3, f4):    
    
    path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
    
    path2 = Conv2D(filters = f2[0], kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(input_layer)
    
    path2 = Conv2D(filters = f2[1], kernel_size = (3,3), 
                   padding = 'same', activation = 'relu')(path2)

    path3 = Conv2D(filters = f3[0], kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(input_layer)
    
    path3 = Conv2D(filters = f3[1], kernel_size = (5,5), 
                   padding = 'same', activation = 'relu')(path3)

    path4 = MaxPooling2D((3,3), strides= (1,1), 
                         padding = 'same')(input_layer)
    
    path4 = Conv2D(filters = f4, kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(path4)
    
    output_layer = concatenate([path1, path2, path3, path4], axis = -1)

    return output_layer

# %%
def Extra_network_2(X):
    X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    X2 = Conv2D(filters = 128, kernel_size = (1,1), 
                padding = 'same', activation = 'relu')(X2)
    
    X2 = Flatten()(X2)
    X2 = Dense(1024, activation = 'relu')(X2)
    X2 = Dropout(0.5)(X2)
    X2 = Dense(n_classes, activation = final_activation, name="output2")(X2)
    return X2


def Extra_network_1(X):
    X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    X1 = Conv2D(filters = 128, kernel_size = (1,1), 
                padding = 'same', activation = 'relu')(X1)
    
    X1 = Flatten()(X1)
    X1 = Dense(1024, activation = 'relu')(X1)
    X1 = Dropout(0.5)(X1)
    X1 = Dense(n_classes, activation = final_activation, name="output1")(X1)
    return X1

# %%
def layer_4(X):
    X = Inception_block(X, 192, (96, 208) , (16, 48), 64)
    
    X1 = Extra_network_1(X)
    
    X = Inception_block(X, 160, (112, 224), (24, 64), 64)
    X = Inception_block(X, 128, (128, 256), (24, 64), 64)
    X = Inception_block(X, 112, (144, 288), (32, 64), 64)
    
    X2 = Extra_network_2(X)
    
    X = Inception_block(X, 256, (160, 320), (32, 128), 128)
    X = MaxPooling2D(pool_size = 3, strides = 2)(X)
    
    return X, X1, X2

def layer_3(X):
    X = Inception_block(X, 64, (96, 128), (16, 32), 32)
    X = Inception_block(X, 128, (128, 192), (32, 96), 64)
    X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)
    
    return X

def layer_2(X):
    X = Conv2D(filters = 64, 
               kernel_size = 1, 
               strides = 1, 
               padding = 'same', 
               activation = 'relu')(X)
    
    X = Conv2D(filters = 192, 
               kernel_size = 3, 
               padding = 'same', 
               activation = 'relu')(X)
    
    X = MaxPooling2D(pool_size= 3, strides = 2)(X)
    
    return X

# %%
def load_GoogLeNet():
    input_layer = Input(shape = input_shape)
    
    X = Conv2D(64, kernel_size = 7, strides = 2, 
               padding = 'valid', activation = 'relu')(input_layer)
    
    X = MaxPooling2D(pool_size = 3, strides = 2)(X)
    
    X = layer_2(X)
    X = layer_3(X)
    X, X1, X2 = layer_4(X)

    X = Inception_block(X, 256, (160, 320), (32, 128), 128)
    X = Inception_block(X, 384, (192, 384), (48, 128), 128)

    X = GlobalAveragePooling2D()(X)
    X = Dropout(0.6)(X)
    
    X = Dense(n_classes, activation = final_activation, name="output3")(X)
  
    model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet')

    return model

load_GoogLeNet().summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 109, 109, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 54, 54, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 54, 54, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 54, 54, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 26, 26, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 26, 26, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 26, 26, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 26, 26, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 26, 26, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 26, 26, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 26, 26, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 26, 26, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 26, 26, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 26, 26, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 26, 26, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 26, 26, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 26, 26, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 26, 26, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 12, 12, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 12, 12, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 12, 12, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 12, 12, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 12, 12, 224)  226016      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 64)   38464       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12, 12, 512)  0           conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 256)  295168      conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 64)   38464       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12, 12, 512)  0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 288)  373536      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 64)   51264       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 528)  0           conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 12, 12, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 320)  461120      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 128)  102528      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 12, 12, 832)  0           conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 5, 5, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 5, 5, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 5, 5, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 5, 5, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 5, 5, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 5, 5, 320)    461120      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 5, 5, 128)    102528      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 5, 5, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 5, 5, 832)    0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 5, 5, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 5, 5, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 5, 5, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 3, 3, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 5, 5, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 5, 5, 384)    663936      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 5, 5, 128)    153728      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 5, 5, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 3, 3, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 3, 3, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 5, 5, 1024)   0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1152)         0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1152)         0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         1180672     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1180672     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# output3 (Dense)                 (None, 3)            3075        dropout_2[0][0]
# __________________________________________________________________________________________________
# output1 (Dense)                 (None, 3)            3075        dropout[0][0]
# __________________________________________________________________________________________________
# output2 (Dense)                 (None, 3)            3075        dropout_1[0][0]
# ==================================================================================================
# Total params: 8,477,497
# Trainable params: 8,477,497
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Get metrics

# %%
def getMetrics(name, type_):
    if name == 'GoogLeNet':
        if type_ == 'accuracy':
            return 'output3_accuracy'
        if type_ == 'loss':
            return 'output3_loss'
        if type_ == 'val_accuracy':
            return 'val_output3_accuracy'
        if type_ == 'val_loss':
            return 'val_output3_loss'
        
    else:
        if type_ == 'accuracy':
            return 'accuracy'
        if type_ == 'loss':
            return 'loss'
        if type_ == 'val_accuracy':
            return 'val_accuracy'
        if type_ == 'val_loss':
            return 'val_loss'

# %% [markdown]
# ## **Setting Call Backs**

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
          
EPOCHS = 120
patience = 10

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8
        
def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
        
def getCallbacks(name):
    class myCallback(Callback):
        def on_epoch_end(self, epoch, logs={}):
            if ((logs.get(getMetrics(name,'accuracy'))>=0.999)):
                print("\nLimits Reached cancelling training!")
                self.model.stop_training = True

            
    end_callback = myCallback()

    lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

    lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

    early_stopping = EarlyStopping(patience = patience, monitor=getMetrics(name, 'val_loss'),
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)


    checkpoint_filepath = name + '_Weights.h5'

    model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor=getMetrics(name, 'val_loss'),
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)

    import datetime
    log_dir="logs/fit/" + '_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  
    tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

    return [end_callback, 
             lr_callback, 
             model_checkpoints,
             early_stopping,
             #tensorboard_callback,
             lr_plat
            ]

GoogLeNet_callbacks = getCallbacks('GoogLeNet')
SwinTransformer_callbacks = getCallbacks('SwinTransformer')
callbacks = getCallbacks('DenseNet121')
Hybrid_callbacks = getCallbacks('HybridTransformer') 
InceptionNet_callbacks = getCallbacks('InceptionNet')
DOLG_callbacks = getCallbacks('DOLGNet')

# %% [markdown]
# ## **Compile Model**

# %%
from tensorflow_addons import optimizers as tfa_optimizers

def CompileModel(name, model):
    if name == 'GoogLeNet':
        model.compile(optimizer='adam', loss=entropy, metrics={"output1":"accuracy", "output2":"accuracy", "output3":"accuracy"})
    else:
        model.compile(optimizer='adam', loss=entropy, metrics=["accuracy"])
    return model

def FitModel(model, name):
    callbacks_ = callbacks
    if name == 'SwinTransformer':
        callbacks_ = SwinTransformer_callbacks
    if name == 'GoogLeNet':
        callbacks_ = GoogLeNet_callbacks
    if name == 'HybridTransformer':
        callbacks_ = Hybrid_callbacks
    if name == 'InceptionNet':
        callbacks_ = InceptionNet_callbacks
    if name == 'DOLGNet':
        callbacks_ = DOLG_callbacks
    history = model.fit(train_generator, 
                        epochs=EPOCHS,
                        callbacks=callbacks_,
                        validation_data = val_generator,
                        steps_per_epoch=(len(train_generator.labels) / 80),
                        validation_steps=(len(val_generator.labels) / 80),
                       )
    
    model.load_weights(name + '_Weights.h5')

    final_accuracy_avg = np.mean(history.history[getMetrics(name, "val_accuracy")][-5:])

    final_loss = history.history[getMetrics(name, "val_loss")][-1]
  
    group = {history: 'history', name: 'name', model: 'model', final_accuracy_avg:'acc', final_loss: 'loss'}

    print('\n')
    print('---'*15)
    print(name,' Model')
    print('Total Epochs :', len(history.history[getMetrics(name, 'loss')]))    
    print('Restoring best Weights')
    
    index = (len(history.history[getMetrics(name, 'loss')]) - (patience + 1))
    print('---'*15)
    print('Best Epoch :', index)
    print('---'*15)
    
    train_accuracy = history.history[getMetrics(name, 'accuracy')][index]
    train_loss = history.history[getMetrics(name, 'loss')][index]
    
    val_accuracy = history.history[getMetrics(name, 'val_accuracy')][index]
    val_loss = history.history[getMetrics(name, 'val_loss')][index]

    print('Accuracy on train:', train_accuracy,
          '\tLoss on train:', train_loss)
    
    print('Accuracy on val:', val_accuracy ,
          '\tLoss on val:', val_loss)
    print('---'*15)

    return model, history

# %%
def BuildModel(name):
    if name == 'GoogLeNet':
        prepared_model = load_GoogLeNet() 
    if name == 'DenseNet121':
        prepared_model = load_DenseNet121()
    if name == 'SwinTransformer':
        prepared_model = load_swin_transformer()
    if name == 'HybridTransformer':
        prepared_model = load_hybrid_swin_transformer()
    if name == 'InceptionNet':
        prepared_model = load_inception_net()
    if name == 'DOLGNet':
        prepared_model = load_DOLG_net()
    compiled_model = CompileModel(name, prepared_model)
    return compiled_model

# %% [markdown]
# ## **Training GoogLeNet**

# %%
g_compiled_model = BuildModel('GoogLeNet')
g_model, g_history = FitModel(g_compiled_model, 'GoogLeNet')
# Out:
# Epoch 1/120
# 289/289 [==============================] - 83s 244ms/step - loss: 3.2886 - output3_loss: 1.0973 - output1_loss: 1.0946 - output2_loss: 1.0967 - output3_accuracy: 0.3457 - output1_accuracy: 0.3625 - output2_accuracy: 0.3315 - val_loss: 3.2730 - val_output3_loss: 1.0945 - val_output1_loss: 1.0878 - val_output2_loss: 1.0907 - val_output3_accuracy: 0.3305 - val_output1_accuracy: 0.5068 - val_output2_accuracy: 0.3305
#
# Epoch 00001: val_output3_loss improved from inf to 1.09446, saving model to GoogLeNet_Weights.h5
# Epoch 2/120
# 289/289 [==============================] - 68s 236ms/step - loss: 3.1972 - output3_loss: 1.0714 - output1_loss: 1.0647 - output2_loss: 1.0610 - output3_accuracy: 0.4125 - output1_accuracy: 0.4409 - output2_accuracy: 0.4379 - val_loss: 2.9371 - val_output3_loss: 0.9852 - val_output1_loss: 0.9966 - val_output2_loss: 0.9553 - val_output3_accuracy: 0.5428 - val_output1_accuracy: 0.6404 - val_output2_accuracy: 0.5668
#
# Epoch 00002: val_output3_loss improved from 1.09446 to 0.98523, saving model to GoogLeNet_Weights.h5
# Epoch 3/120
# 289/289 [==============================] - 68s 236ms/step - loss: 2.7984 - output3_loss: 0.9555 - output1_loss: 0.9291 - output2_loss: 0.9139 - output3_accuracy: 0.5379 - output1_accuracy: 0.5724 - output2_accuracy: 0.5866 - val_loss: 2.5856 - val_output3_loss: 0.9005 - val_output1_loss: 0.8460 - val_output2_loss: 0.8391 - val_output3_accuracy: 0.5428 - val_output1_accuracy: 0.6575 - val_output2_accuracy: 0.6490
#
# Epoch 00003: val_output3_loss improved from 0.98523 to 0.90048, saving model to GoogLeNet_Weights.h5
# Epoch 4/120
# 289/289 [==============================] - 67s 230ms/step - loss: 2.4915 - output3_loss: 0.8566 - output1_loss: 0.8283 - output2_loss: 0.8067 - output3_accuracy: 0.6323 - output1_accuracy: 0.6595 - output2_accuracy: 0.6621 - val_loss: 2.2772 - val_output3_loss: 0.7796 - val_output1_loss: 0.7558 - val_output2_loss: 0.7418 - val_output3_accuracy: 0.6986 - val_output1_accuracy: 0.7038 - val_output2_accuracy: 0.6901
#
# Epoch 00004: val_output3_loss improved from 0.90048 to 0.77959, saving model to GoogLeNet_Weights.h5
# Epoch 5/120
# 289/289 [==============================] - 64s 223ms/step - loss: 2.2663 - output3_loss: 0.7744 - output1_loss: 0.7545 - output2_loss: 0.7375 - output3_accuracy: 0.6703 - output1_accuracy: 0.6909 - output2_accuracy: 0.6948 - val_loss: 2.1525 - val_output3_loss: 0.7140 - val_output1_loss: 0.7359 - val_output2_loss: 0.7026 - val_output3_accuracy: 0.6918 - val_output1_accuracy: 0.6901 - val_output2_accuracy: 0.7089
#
# Epoch 00005: val_output3_loss improved from 0.77959 to 0.71400, saving model to GoogLeNet_Weights.h5
# Epoch 6/120
# 289/289 [==============================] - 63s 217ms/step - loss: 2.1706 - output3_loss: 0.7304 - output1_loss: 0.7284 - output2_loss: 0.7119 - output3_accuracy: 0.6966 - output1_accuracy: 0.6866 - output2_accuracy: 0.6983 - val_loss: 2.0960 - val_output3_loss: 0.6992 - val_output1_loss: 0.7142 - val_output2_loss: 0.6826 - val_output3_accuracy: 0.7089 - val_output1_accuracy: 0.7158 - val_output2_accuracy: 0.7277
#
# Epoch 00006: val_output3_loss improved from 0.71400 to 0.69920, saving model to GoogLeNet_Weights.h5
# Epoch 7/120
# 289/289 [==============================] - 63s 217ms/step - loss: 2.1046 - output3_loss: 0.6969 - output1_loss: 0.7157 - output2_loss: 0.6920 - output3_accuracy: 0.7017 - output1_accuracy: 0.6957 - output2_accuracy: 0.7056 - val_loss: 2.0110 - val_output3_loss: 0.6620 - val_output1_loss: 0.6883 - val_output2_loss: 0.6607 - val_output3_accuracy: 0.7312 - val_output1_accuracy: 0.7295 - val_output2_accuracy: 0.7260
#
# Epoch 00007: val_output3_loss improved from 0.69920 to 0.66199, saving model to GoogLeNet_Weights.h5
# Epoch 8/120
# 289/289 [==============================] - 62s 214ms/step - loss: 1.9418 - output3_loss: 0.6508 - output1_loss: 0.6581 - output2_loss: 0.6328 - output3_accuracy: 0.7349 - output1_accuracy: 0.7246 - output2_accuracy: 0.7483 - val_loss: 1.8517 - val_output3_loss: 0.6014 - val_output1_loss: 0.6441 - val_output2_loss: 0.6063 - val_output3_accuracy: 0.7568 - val_output1_accuracy: 0.7312 - val_output2_accuracy: 0.7414
#
# Epoch 00008: val_output3_loss improved from 0.66199 to 0.60137, saving model to GoogLeNet_Weights.h5
# Epoch 9/120
# 289/289 [==============================] - 62s 215ms/step - loss: 1.8990 - output3_loss: 0.6241 - output1_loss: 0.6580 - output2_loss: 0.6169 - output3_accuracy: 0.7440 - output1_accuracy: 0.7246 - output2_accuracy: 0.7448 - val_loss: 1.7815 - val_output3_loss: 0.5775 - val_output1_loss: 0.6202 - val_output2_loss: 0.5838 - val_output3_accuracy: 0.7740 - val_output1_accuracy: 0.7414 - val_output2_accuracy: 0.7671
#
# Epoch 00009: val_output3_loss improved from 0.60137 to 0.57748, saving model to GoogLeNet_Weights.h5
# Epoch 10/120
# 289/289 [==============================] - 70s 243ms/step - loss: 1.8526 - output3_loss: 0.5999 - output1_loss: 0.6531 - output2_loss: 0.5996 - output3_accuracy: 0.7457 - output1_accuracy: 0.7310 - output2_accuracy: 0.7526 - val_loss: 1.7721 - val_output3_loss: 0.5720 - val_output1_loss: 0.6247 - val_output2_loss: 0.5753 - val_output3_accuracy: 0.7534 - val_output1_accuracy: 0.7397 - val_output2_accuracy: 0.7534
#
# Epoch 00010: val_output3_loss improved from 0.57748 to 0.57203, saving model to GoogLeNet_Weights.h5
# Epoch 11/120
# 289/289 [==============================] - 68s 234ms/step - loss: 1.7365 - output3_loss: 0.5661 - output1_loss: 0.6078 - output2_loss: 0.5625 - output3_accuracy: 0.7711 - output1_accuracy: 0.7539 - output2_accuracy: 0.7789 - val_loss: 1.7668 - val_output3_loss: 0.5837 - val_output1_loss: 0.6074 - val_output2_loss: 0.5757 - val_output3_accuracy: 0.7586 - val_output1_accuracy: 0.7620 - val_output2_accuracy: 0.7654
#
# Epoch 00011: val_output3_loss did not improve from 0.57203
# Epoch 12/120
# 289/289 [==============================] - 64s 220ms/step - loss: 1.7118 - output3_loss: 0.5583 - output1_loss: 0.6029 - output2_loss: 0.5507 - output3_accuracy: 0.7832 - output1_accuracy: 0.7539 - output2_accuracy: 0.7841 - val_loss: 1.6220 - val_output3_loss: 0.5282 - val_output1_loss: 0.5642 - val_output2_loss: 0.5296 - val_output3_accuracy: 0.7945 - val_output1_accuracy: 0.7688 - val_output2_accuracy: 0.7911
#
# Epoch 00012: val_output3_loss improved from 0.57203 to 0.52820, saving model to GoogLeNet_Weights.h5
# Epoch 13/120
# 289/289 [==============================] - 62s 213ms/step - loss: 1.6557 - output3_loss: 0.5368 - output1_loss: 0.5868 - output2_loss: 0.5321 - output3_accuracy: 0.7836 - output1_accuracy: 0.7716 - output2_accuracy: 0.7866 - val_loss: 1.7195 - val_output3_loss: 0.5829 - val_output1_loss: 0.5774 - val_output2_loss: 0.5592 - val_output3_accuracy: 0.7705 - val_output1_accuracy: 0.7654 - val_output2_accuracy: 0.7705
#
# Epoch 00013: val_output3_loss did not improve from 0.52820
# Epoch 14/120
# 289/289 [==============================] - 63s 216ms/step - loss: 1.7010 - output3_loss: 0.5449 - output1_loss: 0.6037 - output2_loss: 0.5524 - output3_accuracy: 0.7815 - output1_accuracy: 0.7552 - output2_accuracy: 0.7819 - val_loss: 1.6835 - val_output3_loss: 0.5421 - val_output1_loss: 0.5901 - val_output2_loss: 0.5513 - val_output3_accuracy: 0.7997 - val_output1_accuracy: 0.7603 - val_output2_accuracy: 0.7997
#
# Epoch 00014: val_output3_loss did not improve from 0.52820
# Epoch 15/120
# 289/289 [==============================] - 64s 220ms/step - loss: 1.6350 - output3_loss: 0.5241 - output1_loss: 0.5762 - output2_loss: 0.5348 - output3_accuracy: 0.8004 - output1_accuracy: 0.7724 - output2_accuracy: 0.7961 - val_loss: 1.5894 - val_output3_loss: 0.5105 - val_output1_loss: 0.5604 - val_output2_loss: 0.5185 - val_output3_accuracy: 0.7945 - val_output1_accuracy: 0.7808 - val_output2_accuracy: 0.7894
#
# Epoch 00015: val_output3_loss improved from 0.52820 to 0.51049, saving model to GoogLeNet_Weights.h5
# Epoch 16/120
# 289/289 [==============================] - 62s 215ms/step - loss: 1.6333 - output3_loss: 0.5243 - output1_loss: 0.5765 - output2_loss: 0.5325 - output3_accuracy: 0.7927 - output1_accuracy: 0.7681 - output2_accuracy: 0.7875 - val_loss: 1.6824 - val_output3_loss: 0.5483 - val_output1_loss: 0.5785 - val_output2_loss: 0.5556 - val_output3_accuracy: 0.7877 - val_output1_accuracy: 0.7586 - val_output2_accuracy: 0.7774
#
# Epoch 00016: val_output3_loss did not improve from 0.51049
# Epoch 17/120
# 289/289 [==============================] - 61s 211ms/step - loss: 1.6246 - output3_loss: 0.5157 - output1_loss: 0.5820 - output2_loss: 0.5269 - output3_accuracy: 0.7961 - output1_accuracy: 0.7659 - output2_accuracy: 0.7897 - val_loss: 1.5591 - val_output3_loss: 0.4989 - val_output1_loss: 0.5563 - val_output2_loss: 0.5038 - val_output3_accuracy: 0.7928 - val_output1_accuracy: 0.7774 - val_output2_accuracy: 0.7877
#
# Epoch 00017: val_output3_loss improved from 0.51049 to 0.49893, saving model to GoogLeNet_Weights.h5
# Epoch 18/120
# 289/289 [==============================] - 63s 218ms/step - loss: 1.5780 - output3_loss: 0.5042 - output1_loss: 0.5689 - output2_loss: 0.5048 - output3_accuracy: 0.8039 - output1_accuracy: 0.7797 - output2_accuracy: 0.8069 - val_loss: 1.5682 - val_output3_loss: 0.5056 - val_output1_loss: 0.5517 - val_output2_loss: 0.5109 - val_output3_accuracy: 0.7945 - val_output1_accuracy: 0.7791 - val_output2_accuracy: 0.7894
#
# Epoch 00018: val_output3_loss did not improve from 0.49893
# Epoch 19/120
# 289/289 [==============================] - 65s 223ms/step - loss: 1.4699 - output3_loss: 0.4616 - output1_loss: 0.5358 - output2_loss: 0.4725 - output3_accuracy: 0.8198 - output1_accuracy: 0.7905 - output2_accuracy: 0.8125 - val_loss: 1.4925 - val_output3_loss: 0.4766 - val_output1_loss: 0.5266 - val_output2_loss: 0.4893 - val_output3_accuracy: 0.8253 - val_output1_accuracy: 0.7911 - val_output2_accuracy: 0.8253
#
# Epoch 00019: val_output3_loss improved from 0.49893 to 0.47664, saving model to GoogLeNet_Weights.h5
# Epoch 20/120
# 289/289 [==============================] - 58s 201ms/step - loss: 1.4628 - output3_loss: 0.4588 - output1_loss: 0.5342 - output2_loss: 0.4697 - output3_accuracy: 0.8259 - output1_accuracy: 0.7935 - output2_accuracy: 0.8194 - val_loss: 1.5232 - val_output3_loss: 0.4837 - val_output1_loss: 0.5496 - val_output2_loss: 0.4898 - val_output3_accuracy: 0.8116 - val_output1_accuracy: 0.7808 - val_output2_accuracy: 0.8099
#
# Epoch 00020: val_output3_loss did not improve from 0.47664
# Epoch 21/120
# 289/289 [==============================] - 59s 203ms/step - loss: 1.4722 - output3_loss: 0.4630 - output1_loss: 0.5336 - output2_loss: 0.4755 - output3_accuracy: 0.8216 - output1_accuracy: 0.7875 - output2_accuracy: 0.8151 - val_loss: 1.4847 - val_output3_loss: 0.4666 - val_output1_loss: 0.5364 - val_output2_loss: 0.4816 - val_output3_accuracy: 0.8322 - val_output1_accuracy: 0.7877 - val_output2_accuracy: 0.8185
#
# Epoch 00021: val_output3_loss improved from 0.47664 to 0.46663, saving model to GoogLeNet_Weights.h5
# Epoch 22/120
# 289/289 [==============================] - 62s 214ms/step - loss: 1.4487 - output3_loss: 0.4636 - output1_loss: 0.5177 - output2_loss: 0.4673 - output3_accuracy: 0.8259 - output1_accuracy: 0.7974 - output2_accuracy: 0.8246 - val_loss: 1.4668 - val_output3_loss: 0.4708 - val_output1_loss: 0.5184 - val_output2_loss: 0.4776 - val_output3_accuracy: 0.8116 - val_output1_accuracy: 0.7860 - val_output2_accuracy: 0.8082
#
# Epoch 00022: val_output3_loss did not improve from 0.46663
# Epoch 23/120
# 289/289 [==============================] - 63s 216ms/step - loss: 1.4214 - output3_loss: 0.4446 - output1_loss: 0.5165 - output2_loss: 0.4603 - output3_accuracy: 0.8341 - output1_accuracy: 0.7991 - output2_accuracy: 0.8267 - val_loss: 1.3866 - val_output3_loss: 0.4371 - val_output1_loss: 0.5027 - val_output2_loss: 0.4468 - val_output3_accuracy: 0.8288 - val_output1_accuracy: 0.7962 - val_output2_accuracy: 0.8253
#
# Epoch 00023: val_output3_loss improved from 0.46663 to 0.43708, saving model to GoogLeNet_Weights.h5
# Epoch 24/120
# 289/289 [==============================] - 62s 214ms/step - loss: 1.4861 - output3_loss: 0.4677 - output1_loss: 0.5398 - output2_loss: 0.4787 - output3_accuracy: 0.8147 - output1_accuracy: 0.7776 - output2_accuracy: 0.8138 - val_loss: 1.6028 - val_output3_loss: 0.5493 - val_output1_loss: 0.5298 - val_output2_loss: 0.5237 - val_output3_accuracy: 0.7757 - val_output1_accuracy: 0.7740 - val_output2_accuracy: 0.7723
#
# Epoch 00024: val_output3_loss did not improve from 0.43708
# Epoch 25/120
# 289/289 [==============================] - 62s 212ms/step - loss: 1.4098 - output3_loss: 0.4447 - output1_loss: 0.5137 - output2_loss: 0.4514 - output3_accuracy: 0.8263 - output1_accuracy: 0.7987 - output2_accuracy: 0.8190 - val_loss: 1.3683 - val_output3_loss: 0.4320 - val_output1_loss: 0.4987 - val_output2_loss: 0.4376 - val_output3_accuracy: 0.8373 - val_output1_accuracy: 0.8082 - val_output2_accuracy: 0.8390
#
# Epoch 00025: val_output3_loss improved from 0.43708 to 0.43205, saving model to GoogLeNet_Weights.h5
# Epoch 26/120
# 289/289 [==============================] - 61s 212ms/step - loss: 1.4447 - output3_loss: 0.4566 - output1_loss: 0.5227 - output2_loss: 0.4655 - output3_accuracy: 0.8323 - output1_accuracy: 0.7931 - output2_accuracy: 0.8259 - val_loss: 1.4589 - val_output3_loss: 0.4662 - val_output1_loss: 0.5268 - val_output2_loss: 0.4659 - val_output3_accuracy: 0.8271 - val_output1_accuracy: 0.8031 - val_output2_accuracy: 0.8253
#
# Epoch 00026: val_output3_loss did not improve from 0.43205
# Epoch 27/120
# 289/289 [==============================] - 63s 217ms/step - loss: 1.4251 - output3_loss: 0.4483 - output1_loss: 0.5180 - output2_loss: 0.4588 - output3_accuracy: 0.8272 - output1_accuracy: 0.7871 - output2_accuracy: 0.8142 - val_loss: 1.3460 - val_output3_loss: 0.4167 - val_output1_loss: 0.4960 - val_output2_loss: 0.4333 - val_output3_accuracy: 0.8459 - val_output1_accuracy: 0.8202 - val_output2_accuracy: 0.8322
#
# Epoch 00027: val_output3_loss improved from 0.43205 to 0.41671, saving model to GoogLeNet_Weights.h5
# Epoch 28/120
# 289/289 [==============================] - 61s 212ms/step - loss: 1.3450 - output3_loss: 0.4247 - output1_loss: 0.4893 - output2_loss: 0.4311 - output3_accuracy: 0.8444 - output1_accuracy: 0.8155 - output2_accuracy: 0.8414 - val_loss: 1.4224 - val_output3_loss: 0.4602 - val_output1_loss: 0.5014 - val_output2_loss: 0.4608 - val_output3_accuracy: 0.8134 - val_output1_accuracy: 0.7911 - val_output2_accuracy: 0.8048
#
# Epoch 00028: val_output3_loss did not improve from 0.41671
# Epoch 29/120
# 289/289 [==============================] - 60s 207ms/step - loss: 1.4752 - output3_loss: 0.4665 - output1_loss: 0.5357 - output2_loss: 0.4731 - output3_accuracy: 0.8147 - output1_accuracy: 0.7927 - output2_accuracy: 0.8151 - val_loss: 1.3595 - val_output3_loss: 0.4337 - val_output1_loss: 0.4900 - val_output2_loss: 0.4358 - val_output3_accuracy: 0.8356 - val_output1_accuracy: 0.8065 - val_output2_accuracy: 0.8356
#
# Epoch 00029: val_output3_loss did not improve from 0.41671
# Epoch 30/120
# 289/289 [==============================] - 66s 227ms/step - loss: 1.4070 - output3_loss: 0.4436 - output1_loss: 0.5109 - output2_loss: 0.4525 - output3_accuracy: 0.8302 - output1_accuracy: 0.7996 - output2_accuracy: 0.8177 - val_loss: 1.3919 - val_output3_loss: 0.4416 - val_output1_loss: 0.5017 - val_output2_loss: 0.4487 - val_output3_accuracy: 0.8288 - val_output1_accuracy: 0.7979 - val_output2_accuracy: 0.8305
#
# Epoch 00030: val_output3_loss did not improve from 0.41671
# Epoch 31/120
# 289/289 [==============================] - 64s 222ms/step - loss: 1.4240 - output3_loss: 0.4503 - output1_loss: 0.5178 - output2_loss: 0.4560 - output3_accuracy: 0.8211 - output1_accuracy: 0.7922 - output2_accuracy: 0.8203 - val_loss: 1.3907 - val_output3_loss: 0.4346 - val_output1_loss: 0.5066 - val_output2_loss: 0.4495 - val_output3_accuracy: 0.8322 - val_output1_accuracy: 0.7997 - val_output2_accuracy: 0.8322
#
# Epoch 00031: val_output3_loss did not improve from 0.41671
# Epoch 32/120
# 289/289 [==============================] - 63s 218ms/step - loss: 1.4059 - output3_loss: 0.4458 - output1_loss: 0.5124 - output2_loss: 0.4477 - output3_accuracy: 0.8310 - output1_accuracy: 0.7996 - output2_accuracy: 0.8319 - val_loss: 1.3722 - val_output3_loss: 0.4334 - val_output1_loss: 0.4965 - val_output2_loss: 0.4422 - val_output3_accuracy: 0.8305 - val_output1_accuracy: 0.8031 - val_output2_accuracy: 0.8271
#
# Epoch 00032: val_output3_loss did not improve from 0.41671
# Epoch 33/120
# 289/289 [==============================] - 67s 230ms/step - loss: 1.4359 - output3_loss: 0.4513 - output1_loss: 0.5287 - output2_loss: 0.4559 - output3_accuracy: 0.8147 - output1_accuracy: 0.7823 - output2_accuracy: 0.8116 - val_loss: 1.3430 - val_output3_loss: 0.4273 - val_output1_loss: 0.4829 - val_output2_loss: 0.4327 - val_output3_accuracy: 0.8356 - val_output1_accuracy: 0.8065 - val_output2_accuracy: 0.8322
#
# Epoch 00033: val_output3_loss did not improve from 0.41671
# Epoch 34/120
# 289/289 [==============================] - 63s 216ms/step - loss: 1.4414 - output3_loss: 0.4482 - output1_loss: 0.5321 - output2_loss: 0.4611 - output3_accuracy: 0.8259 - output1_accuracy: 0.7802 - output2_accuracy: 0.8207 - val_loss: 1.3578 - val_output3_loss: 0.4271 - val_output1_loss: 0.4930 - val_output2_loss: 0.4377 - val_output3_accuracy: 0.8322 - val_output1_accuracy: 0.8082 - val_output2_accuracy: 0.8356
#
# Epoch 00034: val_output3_loss did not improve from 0.41671
# Epoch 35/120
# 289/289 [==============================] - 62s 215ms/step - loss: 1.3974 - output3_loss: 0.4335 - output1_loss: 0.5161 - output2_loss: 0.4477 - output3_accuracy: 0.8332 - output1_accuracy: 0.7931 - output2_accuracy: 0.8259 - val_loss: 1.5772 - val_output3_loss: 0.5143 - val_output1_loss: 0.5472 - val_output2_loss: 0.5157 - val_output3_accuracy: 0.8253 - val_output1_accuracy: 0.7928 - val_output2_accuracy: 0.8134
#
# Epoch 00035: val_output3_loss did not improve from 0.41671
# Epoch 36/120
# 289/289 [==============================] - 65s 226ms/step - loss: 1.3901 - output3_loss: 0.4406 - output1_loss: 0.5041 - output2_loss: 0.4454 - output3_accuracy: 0.8254 - output1_accuracy: 0.8047 - output2_accuracy: 0.8207 - val_loss: 1.3345 - val_output3_loss: 0.4216 - val_output1_loss: 0.4751 - val_output2_loss: 0.4378 - val_output3_accuracy: 0.8356 - val_output1_accuracy: 0.8134 - val_output2_accuracy: 0.8305
#
# Epoch 00036: val_output3_loss did not improve from 0.41671
# Epoch 37/120
# 289/289 [==============================] - 62s 216ms/step - loss: 1.3571 - output3_loss: 0.4250 - output1_loss: 0.4944 - output2_loss: 0.4378 - output3_accuracy: 0.8366 - output1_accuracy: 0.8034 - output2_accuracy: 0.8362 - val_loss: 1.3338 - val_output3_loss: 0.4261 - val_output1_loss: 0.4776 - val_output2_loss: 0.4300 - val_output3_accuracy: 0.8356 - val_output1_accuracy: 0.8202 - val_output2_accuracy: 0.8408
#
# Epoch 00037: val_output3_loss did not improve from 0.41671
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
#
#
# ---------------------------------------------
# GoogLeNet  Model
# Total Epochs : 37
# Restoring best Weights
# ---------------------------------------------
# Best Epoch : 26
# ---------------------------------------------
# Accuracy on train: 0.8271551728248596 	Loss on train: 0.44828253984451294
# Accuracy on val: 0.8458904027938843 	Loss on val: 0.4167117178440094
# ---------------------------------------------

# %% [markdown]
# ## **Model Evaluation on the TestSet**

# %%
# %matplotlib inline
def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve, accuracy_score, classification_report, confusion_matrix

def test_set_results(pred_value, n=1):    
    y_test = test_generator.labels
    X_test, _ = test_generator.next()
    
    corr_pred = metrics.confusion_matrix(y_test, pred_value)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Dense Output {}'.format(n))
    plt.show()
    
    n_correct = np.int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_generator.labels, pred_value, target_names=CATEGORIES))

# %%
def printResults(name, model):
    predictions = model.predict(test_generator, verbose=1)
    preds = np.argmax(predictions, axis=1)
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    index = (len(history.history[getMetrics(name, 'loss')]) - (patience + 1))
    print('Best Epochs: ', index)
    
    if name == 'GoogLeNet':
        results = model.evaluate(test_generator, verbose=1)
        loss, output3_loss, output1_loss, output2_loss, output3_accuracy, output1_accuracy, output2_accuracy = results
        
        for i in range(3):
            n = i + 1
            out_layer = 'Output Layer {}'.format(n)
            
            if n == 1:
                test_accuracy = output1_accuracy
                test_loss = output1_loss

            if n == 2:
                test_accuracy = output2_accuracy
                test_loss = output2_loss
                
            if n == 3:
                test_accuracy = output3_accuracy
                test_loss = output3_loss
                
                
            output_name = 'output{}_'.format(n)
            train_accuracy, train_loss = history.history[output_name + 'accuracy'][index], history.history[output_name + 'loss'][index]
            
  
            print_graph(output_name + 'loss', index, history)
            print_graph(output_name + 'accuracy', index, history)
        
            print('---'*15)  
            print('GoogLeNet Dense output {}:'.format(n))
            
            print('> Accuracy on train :'.format(out_layer), train_accuracy, 
                  '\tLoss on train:',train_loss)
        
            print('> Accuracy on test :'.format(out_layer), test_accuracy,
                  '\tLoss on test:',test_loss)
            
            print('---'*15)
            print('> predicting test')
            print('---'*15)
            
            predictions = model.predict(test_generator, verbose=1)
            preds = np.argmax(predictions[i], axis=1)
            test_set_results(preds, n)
                
    else:
        test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
        
        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        
        print('---'*15) 
        print(name)
        print('> Accuracy on train:',train_accuracy, 
              '\tLoss on train:',train_loss)
        
        print('> Accuracy on test:',test_accuracy,
              '\tLoss on test:',test_loss)
        
        print('---'*15)
        print('> predicting test')
        print('---'*15)
        
        printResults(name, model)

# %% [markdown]
# ## **GoogLeNet Results**

# %%
model_summary(g_model, g_history, 'GoogLeNet')
# Out:
# Best Epochs:  26
# 50/50 [==============================] - 28s 555ms/step - loss: 1.9554 - output3_loss: 0.6526 - output1_loss: 0.6765 - output2_loss: 0.6262 - output3_accuracy: 0.7225 - output1_accuracy: 0.6950 - output2_accuracy: 0.7450
# ---------------------------------------------
# GoogLeNet Dense output 1:
# > Accuracy on train : 0.7870689630508423 	Loss on train: 0.5180094838142395
# > Accuracy on test : 0.6949999928474426 	Loss on test: 0.6764917969703674
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 50/50 [==============================] - 24s 465ms/step
# .............................................
# > Correct Predictions: 297
# > Wrong Predictions: 103
# .............................................
#               precision    recall  f1-score   support
#
#        COVID       0.85      0.70      0.77       200
#       NORMAL       0.57      0.90      0.70       100
#    PNEUMONIA       0.85      0.67      0.75       100
#
#     accuracy                           0.74       400
#    macro avg       0.76      0.76      0.74       400
# weighted avg       0.78      0.74      0.75       400
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_27136/2559713061.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
# ---------------------------------------------
# GoogLeNet Dense output 2:
# > Accuracy on train : 0.814224123954773 	Loss on train: 0.458837628364563
# > Accuracy on test : 0.7450000047683716 	Loss on test: 0.6262207627296448
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 50/50 [==============================] - 24s 482ms/step
# .............................................
# > Correct Predictions: 282
# > Wrong Predictions: 118
# .............................................
#               precision    recall  f1-score   support
#
#        COVID       0.82      0.67      0.74       200
#       NORMAL       0.54      0.87      0.66       100
#    PNEUMONIA       0.81      0.61      0.70       100
#
#     accuracy                           0.70       400
#    macro avg       0.72      0.72      0.70       400
# weighted avg       0.75      0.70      0.71       400
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_27136/2559713061.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
# ---------------------------------------------
# GoogLeNet Dense output 3:
# > Accuracy on train : 0.8271551728248596 	Loss on train: 0.44828253984451294
# > Accuracy on test : 0.7225000262260437 	Loss on test: 0.6526427268981934
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 50/50 [==============================] - 24s 478ms/step
# .............................................
# > Correct Predictions: 294
# > Wrong Predictions: 106
# .............................................
#               precision    recall  f1-score   support
#
#        COVID       0.85      0.68      0.75       200
#       NORMAL       0.57      0.90      0.70       100
#    PNEUMONIA       0.83      0.69      0.75       100
#
#     accuracy                           0.73       400
#    macro avg       0.75      0.76      0.73       400
# weighted avg       0.77      0.73      0.74       400
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_27136/2559713061.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1] + corr_pred[2][2])
