# %% [markdown]
# ## **Chest X-ray classification between Covid, pneumonia, normal using GoogleNet**
#
# + **About**:
#     + This notebook contains code to run experiments for paper: Covid-19 Chest X-ray classification and severity assessment using Convolutional and Transformer Neural Networks
#
# + **Datasets**:
#     + The COVID CXR dataset
#     + The Chest Xray Pneumonia dataset
#
#
# + **Classes**:
#     + Normal
#     + Pneumonia
#     + Covid_19
#
# + **Architecture**:
#     + GoogLeNet

# %%
import os
import cv2
import platform
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from IPython.display import clear_output

os.environ['PYTHONHASHSEED'] = '73'

seed = 73
random.seed(seed)
np.random.seed(seed)

print(platform.platform())
# %matplotlib inline
# Out:
# Windows-10-10.0.19043-SP0

# %%
three_classes_covid_xray_balanced = "/Users/MCSP_Lab/Desktop/covidx-dataset/covidx-cxr2/datasets/severity_dataset/joined_RALO_Brook/train"

# %%
print('> train_covidx9a_balance_9449 dir:', os.listdir(three_classes_covid_xray_balanced))
# Out:
# > train_covidx9a_balance_9449 dir: ['level1', 'level2']

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### Read train_df

# %%
from tqdm import tqdm

train_image_dir = three_classes_covid_xray_balanced 
img_map = []

def prepareData(Dir, strat):
    cats = ["level1","level2"]
    for category in cats:
        path = os.path.join(Dir,category)
        class_num = cats.index(category)
        
        for img in tqdm(os.listdir(path)):
            img_path = os.path.join(path,img)
            img_map.append({'path': img_path, 'label': category})

prepareData(train_image_dir,'train')
img_map_covidx9a = pd.DataFrame(img_map).sample(frac = 1, random_state=seed)
# Out:
# 100%|██████████| 1231/1231 [00:00<00:00, 307919.15it/s]
# 100%|██████████| 1901/1901 [00:00<00:00, 316090.07it/s]

# %%
img_map_covidx9a.head()
# Out:
#                                                    path   label
# 2402  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level2
# 418   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1
# 1516  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level2
# 106   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1
# 441   /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1

# %% [markdown]
# ### Read test_df

# %%
from tqdm import tqdm

test_image_dir = "/Users/MCSP_Lab/Desktop/covidx-dataset/covidx-cxr2/datasets/severity_dataset/joined_RALO_Brook/test/"

img_map = []

def prepareData(Dir, strat):
    cats = ["level1", "level2"]
    for category in cats:
        path = os.path.join(Dir,category)
        class_num = cats.index(category)
        
        for img in tqdm(os.listdir(path)):
            img_path = os.path.join(path,img)
            img_map.append({'path': img_path, 'label': category})

prepareData(test_image_dir,'train')
test_img_map_covidx9a = pd.DataFrame(img_map).sample(frac = 1, random_state=seed)
# Out:
# 100%|██████████| 52/52 [00:00<?, ?it/s]
# 100%|██████████| 98/98 [00:00<00:00, 98547.54it/s]

# %% [markdown]
# ### Images Visualization

# %%
import matplotlib.pyplot as plt

def print_images(samples): 
    images = samples["path"].to_numpy()
    labels = samples['label'].to_numpy()
    
    fig=plt.figure(figsize=(20, 8))
    columns = 4
    rows = 1
    
    for i, image_path in enumerate(images):
        image = cv2.imread(image_path, cv2.IMREAD_COLOR)
        
        fig.add_subplot(rows,columns,i + 1)
        title = '{}'.format(labels[i])
        
        Sample_image = cv2.resize(image, (224, 224), interpolation = cv2.INTER_CUBIC)
        
        plt.imshow(Sample_image, cmap='gray')
        plt.title(title)
        
    plt.show()
        
print_images(img_map_covidx9a[img_map_covidx9a['label']=="level1"].iloc[0:4])
print_images(img_map_covidx9a[img_map_covidx9a['label']=="level2"].iloc[0:4])
#print_images(img_map_covidx9a[img_map_covidx9a['label']=="COVID-19"].iloc[0:4])

# %matplotlib inline

# %%
def getLabelCount(frame):
    label_count = pd.Series(frame['label'].values.ravel()).value_counts()
    n_classes = (label_count)
    return label_count

label_count = getLabelCount(img_map_covidx9a)
print(label_count)
# Out:
# level2    1901
# level1    1231
# dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

features = img_map_covidx9a['path'].to_numpy()
labels = img_map_covidx9a['label'].to_numpy()

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.2, random_state=73)

# %%
for train_index, val_index in stratified_sample.split(features, labels):
    X_train, val_X = features[train_index], features[val_index]
    y_train, val_y = labels[train_index], labels[val_index]
    
half_size = np.int(len(val_X))
X_val, y_val = val_X[0:half_size], val_y[0:half_size]
# Out:
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_5084/2451442638.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   half_size = np.int(len(val_X))

# %%
train_map = pd.DataFrame()
train_map['path'], train_map['label'] = X_train, y_train

# %%
val_map = pd.DataFrame()
val_map['path'], val_map['label'] = X_val, y_val

# %%
# data summary
print('> {} train size'.format(X_train.shape[0]))
print('> {} val size'.format(X_val.shape[0]))
# Out:
# > 2505 train size
# > 627 val size

# %%
train_map.head()
# Out:
#                                                 path   label
# 0  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1
# 1  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1
# 2  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level2
# 3  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1
# 4  /Users/MCSP_Lab/Desktop/covidx-dataset/covidx-...  level1

# %% [markdown]
# ### Data Augmentation

# %%
import cv2
import time
import imageio
import imgaug.augmenters as iaa
import imgaug as ia
ia.seed(73)

ColorCh = 3
#IMG_SIZE = 224
IMG_SIZE = 224
input_shape=(IMG_SIZE, IMG_SIZE, ColorCh)

classes = ("level1", "level2")
CATEGORIES = sorted(classes)

print('> Classes:',CATEGORIES)
# Out:
# > Classes: ['level1', 'level2']

# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

datagen = ImageDataGenerator(rescale = 1./255, 
                             horizontal_flip=True,
                             brightness_range=[1.0,1.3],
                             rotation_range=15,
                             #zoom_range=0.2
                            )

# %%
batch_size = 8

def get_generator(frame_):
    generator = datagen.flow_from_dataframe(
                          dataframe=frame_,
                          x_col="path",
                          y_col="label",
                          batch_size=batch_size,
                          seed=seed,
                          shuffle=False,
                          class_mode="sparse",
                          color_mode="rgb",
                          save_format="jpeg",
                          target_size=(IMG_SIZE,IMG_SIZE)             
             )
    
    return generator

# %% [markdown]
# ### Get train_generator

# %%
train_df = train_map.sample(frac=1, random_state=seed)
train_generator = get_generator(train_df)

print('> label count for train set')
getLabelCount(train_df)
# Out:
# Found 2505 validated image filenames belonging to 2 classes.
# > label count for train set
# level2    1520
# level1     985
# dtype: int64

# %%
val_df = val_map.sample(frac=1, random_state=seed)
val_generator = get_generator(val_df)

print('> label count for val set')
getLabelCount(val_df)
# Out:
# Found 627 validated image filenames belonging to 2 classes.
# > label count for val set
# level2    381
# level1    246
# dtype: int64

# %%
test_generator = get_generator(test_img_map_covidx9a)

print('> label count for test set')
getLabelCount(test_img_map_covidx9a)
# Out:
# Found 150 validated image filenames belonging to 2 classes.
# > label count for test set
# level2    98
# level1    52
# dtype: int64

# %%
print('> input shape:', input_shape)
# Out:
# > input shape: (224, 224, 3)

# %% [markdown]
# ## **Model Construction**

# %%
import keras
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Add, add
from tensorflow.keras.layers import InputLayer, Input, Conv2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, Activation, MaxPool2D, ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model, Sequential
from keras import regularizers

kernel_regularizer = regularizers.l2(0.0001)

final_activation = 'softmax'
entropy = 'sparse_categorical_crossentropy'
n_classes = len(CATEGORIES)
print('> {} classes'.format(n_classes))
# Out:
# > 2 classes

# %%
def FCLayers(baseModel):
    baseModel.trainable = True
    headModel = baseModel.output
    headModel = Dropout(0.5, seed=73)(headModel)
    headModel = Dense(n_classes, activation=final_activation)(headModel)
    
    model = Model(inputs = baseModel.input, outputs = headModel)
    return model

# %% [markdown]
# ### Build GoogleNet

# %%
from keras.layers.merge import concatenate

def Inception_block(input_layer, f1, f2, f3, f4):    
    
    path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
    
    path2 = Conv2D(filters = f2[0], kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(input_layer)
    
    path2 = Conv2D(filters = f2[1], kernel_size = (3,3), 
                   padding = 'same', activation = 'relu')(path2)

    path3 = Conv2D(filters = f3[0], kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(input_layer)
    
    path3 = Conv2D(filters = f3[1], kernel_size = (5,5), 
                   padding = 'same', activation = 'relu')(path3)

    path4 = MaxPooling2D((3,3), strides= (1,1), 
                         padding = 'same')(input_layer)
    
    path4 = Conv2D(filters = f4, kernel_size = (1,1), 
                   padding = 'same', activation = 'relu')(path4)
    
    output_layer = concatenate([path1, path2, path3, path4], axis = -1)

    return output_layer

# %%
def Extra_network_2(X):
    X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    X2 = Conv2D(filters = 128, kernel_size = (1,1), 
                padding = 'same', activation = 'relu')(X2)
    
    X2 = Flatten()(X2)
    X2 = Dense(1024, activation = 'relu')(X2)
    X2 = Dropout(0.5)(X2)
    X2 = Dense(n_classes, activation = final_activation, name="output2")(X2)
    return X2


def Extra_network_1(X):
    X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
    X1 = Conv2D(filters = 128, kernel_size = (1,1), 
                padding = 'same', activation = 'relu')(X1)
    
    X1 = Flatten()(X1)
    X1 = Dense(1024, activation = 'relu')(X1)
    X1 = Dropout(0.5)(X1)
    X1 = Dense(n_classes, activation = final_activation, name="output1")(X1)
    return X1

# %%
def layer_4(X):
    X = Inception_block(X, 192, (96, 208) , (16, 48), 64)
    
    X1 = Extra_network_1(X)
    
    X = Inception_block(X, 160, (112, 224), (24, 64), 64)
    X = Inception_block(X, 128, (128, 256), (24, 64), 64)
    X = Inception_block(X, 112, (144, 288), (32, 64), 64)
    
    X2 = Extra_network_2(X)
    
    X = Inception_block(X, 256, (160, 320), (32, 128), 128)
    X = MaxPooling2D(pool_size = 3, strides = 2)(X)
    
    return X, X1, X2

def layer_3(X):
    X = Inception_block(X, 64, (96, 128), (16, 32), 32)
    X = Inception_block(X, 128, (128, 192), (32, 96), 64)
    X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)
    
    return X

def layer_2(X):
    X = Conv2D(filters = 64, 
               kernel_size = 1, 
               strides = 1, 
               padding = 'same', 
               activation = 'relu')(X)
    
    X = Conv2D(filters = 192, 
               kernel_size = 3, 
               padding = 'same', 
               activation = 'relu')(X)
    
    X = MaxPooling2D(pool_size= 3, strides = 2)(X)
    
    return X

# %%
def load_GoogLeNet():
    input_layer = Input(shape = input_shape)
    
    X = Conv2D(64, kernel_size = 7, strides = 2, 
               padding = 'valid', activation = 'relu')(input_layer)
    
    X = MaxPooling2D(pool_size = 3, strides = 2)(X)
    
    X = layer_2(X)
    X = layer_3(X)
    X, X1, X2 = layer_4(X)

    X = Inception_block(X, 256, (160, 320), (32, 128), 128)
    X = Inception_block(X, 384, (192, 384), (48, 128), 128)

    X = GlobalAveragePooling2D()(X)
    X = Dropout(0.6)(X)
    
    X = Dense(n_classes, activation = final_activation, name="output3")(X)
  
    model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet')

    return model

load_GoogLeNet().summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 109, 109, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 54, 54, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 54, 54, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 54, 54, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 26, 26, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 26, 26, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 26, 26, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 26, 26, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 26, 26, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 26, 26, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 26, 26, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 26, 26, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 26, 26, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 26, 26, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 26, 26, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 26, 26, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 26, 26, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 26, 26, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 26, 26, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 12, 12, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 12, 12, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 12, 12, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 12, 12, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 12, 12, 224)  226016      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 64)   38464       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 12, 12, 512)  0           conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 256)  295168      conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 64)   38464       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12, 12, 512)  0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 12, 12, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 12, 12, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 288)  373536      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 12, 12, 64)   51264       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 12, 12, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 528)  0           conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 12, 12, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 12, 12, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 12, 12, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 12, 12, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 12, 12, 320)  461120      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 12, 12, 128)  102528      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 12, 12, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 12, 12, 832)  0           conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 5, 5, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 5, 5, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 5, 5, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 5, 5, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 5, 5, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 5, 5, 320)    461120      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 5, 5, 128)    102528      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 5, 5, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 5, 5, 832)    0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 5, 5, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 5, 5, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 5, 5, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 3, 3, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 5, 5, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 5, 5, 384)    663936      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 5, 5, 128)    153728      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 5, 5, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 3, 3, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 3, 3, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 5, 5, 1024)   0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1152)         0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1152)         0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         1180672     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         1180672     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# output3 (Dense)                 (None, 2)            2050        dropout_2[0][0]
# __________________________________________________________________________________________________
# output1 (Dense)                 (None, 2)            2050        dropout[0][0]
# __________________________________________________________________________________________________
# output2 (Dense)                 (None, 2)            2050        dropout_1[0][0]
# ==================================================================================================
# Total params: 8,474,422
# Trainable params: 8,474,422
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Get metrics

# %%
def getMetrics(name, type_):
    if name == 'GoogLeNet':
        if type_ == 'accuracy':
            return 'output3_accuracy'
        if type_ == 'loss':
            return 'output3_loss'
        if type_ == 'val_accuracy':
            return 'val_output3_accuracy'
        if type_ == 'val_loss':
            return 'val_output3_loss'
        
    else:
        if type_ == 'accuracy':
            return 'accuracy'
        if type_ == 'loss':
            return 'loss'
        if type_ == 'val_accuracy':
            return 'val_accuracy'
        if type_ == 'val_loss':
            return 'val_loss'

# %% [markdown]
# ## **Setting Call Backs**

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
          
EPOCHS = 120
patience = 10

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8
        
def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
        
def getCallbacks(name):
    class myCallback(Callback):
        def on_epoch_end(self, epoch, logs={}):
            if ((logs.get(getMetrics(name,'accuracy'))>=0.999)):
                print("\nLimits Reached cancelling training!")
                self.model.stop_training = True

            
    end_callback = myCallback()

    lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

    lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

    early_stopping = EarlyStopping(patience = patience, monitor=getMetrics(name, 'val_loss'),
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)


    checkpoint_filepath = name + '_Weights.h5'

    model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor=getMetrics(name, 'val_loss'),
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)

    import datetime
    log_dir="logs/fit/" + '_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  
    tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

    return [end_callback, 
             lr_callback, 
             model_checkpoints,
             early_stopping,
             #tensorboard_callback,
             lr_plat
            ]

GoogLeNet_callbacks = getCallbacks('GoogLeNet')
SwinTransformer_callbacks = getCallbacks('SwinTransformer')
callbacks = getCallbacks('DenseNet121')
Hybrid_callbacks = getCallbacks('HybridTransformer') 
InceptionNet_callbacks = getCallbacks('InceptionNet')
DOLG_callbacks = getCallbacks('DOLGNet')

# %% [markdown]
# ## **Compile Model**

# %%
from tensorflow_addons import optimizers as tfa_optimizers

def CompileModel(name, model):
    if name == 'GoogLeNet':
        model.compile(optimizer='adam', loss=entropy, metrics={"output1":"accuracy", "output2":"accuracy", "output3":"accuracy"})
    else:
        model.compile(optimizer='adam', loss=entropy, metrics=["accuracy"])
    return model

def FitModel(model, name):
    callbacks_ = callbacks
    if name == 'SwinTransformer':
        callbacks_ = SwinTransformer_callbacks
    if name == 'GoogLeNet':
        callbacks_ = GoogLeNet_callbacks
    if name == 'HybridTransformer':
        callbacks_ = Hybrid_callbacks
    if name == 'InceptionNet':
        callbacks_ = InceptionNet_callbacks
    if name == 'DOLGNet':
        callbacks_ = DOLG_callbacks
    history = model.fit(train_generator, 
                        epochs=EPOCHS,
                        callbacks=callbacks_,
                        validation_data = val_generator,
                        steps_per_epoch=(len(train_generator.labels) / 80),
                        validation_steps=(len(val_generator.labels) / 80),
                       )
    
    model.load_weights(name + '_Weights.h5')

    final_accuracy_avg = np.mean(history.history[getMetrics(name, "val_accuracy")][-5:])

    final_loss = history.history[getMetrics(name, "val_loss")][-1]
  
    group = {history: 'history', name: 'name', model: 'model', final_accuracy_avg:'acc', final_loss: 'loss'}

    print('\n')
    print('---'*15)
    print(name,' Model')
    print('Total Epochs :', len(history.history[getMetrics(name, 'loss')]))    
    print('Restoring best Weights')
    
    index = (len(history.history[getMetrics(name, 'loss')]) - (patience + 1))
    print('---'*15)
    print('Best Epoch :', index)
    print('---'*15)
    
    train_accuracy = history.history[getMetrics(name, 'accuracy')][index]
    train_loss = history.history[getMetrics(name, 'loss')][index]
    
    val_accuracy = history.history[getMetrics(name, 'val_accuracy')][index]
    val_loss = history.history[getMetrics(name, 'val_loss')][index]

    print('Accuracy on train:', train_accuracy,
          '\tLoss on train:', train_loss)
    
    print('Accuracy on val:', val_accuracy ,
          '\tLoss on val:', val_loss)
    print('---'*15)

    return model, history

# %%
def BuildModel(name):
    if name == 'GoogLeNet':
        prepared_model = load_GoogLeNet() 
    if name == 'DenseNet121':
        prepared_model = load_DenseNet121()
    if name == 'SwinTransformer':
        prepared_model = load_swin_transformer()
    if name == 'HybridTransformer':
        prepared_model = load_hybrid_swin_transformer()
    if name == 'InceptionNet':
        prepared_model = load_inception_net()
    if name == 'DOLGNet':
        prepared_model = load_DOLG_net()
    compiled_model = CompileModel(name, prepared_model)
    return compiled_model

# %% [markdown]
# ## **Training GoogLeNet**

# %%
g_compiled_model = BuildModel('GoogLeNet')
g_model, g_history = FitModel(g_compiled_model, 'GoogLeNet')
# Out:
# Epoch 1/120
# 31/31 [==============================] - 13s 302ms/step - loss: 2.0747 - output3_loss: 0.6925 - output1_loss: 0.6904 - output2_loss: 0.6919 - output3_accuracy: 0.5430 - output1_accuracy: 0.5625 - output2_accuracy: 0.5273 - val_loss: 2.0761 - val_output3_loss: 0.6925 - val_output1_loss: 0.6915 - val_output2_loss: 0.6922 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00001: val_output3_loss did not improve from 0.54728
# Epoch 2/120
# 31/31 [==============================] - 9s 275ms/step - loss: 2.0622 - output3_loss: 0.6892 - output1_loss: 0.6852 - output2_loss: 0.6878 - output3_accuracy: 0.5898 - output1_accuracy: 0.5898 - output2_accuracy: 0.5898 - val_loss: 2.0760 - val_output3_loss: 0.6911 - val_output1_loss: 0.6935 - val_output2_loss: 0.6914 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00002: val_output3_loss did not improve from 0.54728
# Epoch 3/120
# 31/31 [==============================] - 8s 255ms/step - loss: 1.9699 - output3_loss: 0.6597 - output1_loss: 0.6563 - output2_loss: 0.6539 - output3_accuracy: 0.6641 - output1_accuracy: 0.6641 - output2_accuracy: 0.6641 - val_loss: 2.1476 - val_output3_loss: 0.7136 - val_output1_loss: 0.7111 - val_output2_loss: 0.7229 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00003: val_output3_loss did not improve from 0.54728
# Epoch 4/120
# 31/31 [==============================] - 8s 261ms/step - loss: 2.0207 - output3_loss: 0.6736 - output1_loss: 0.6765 - output2_loss: 0.6706 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 2.0786 - val_output3_loss: 0.6914 - val_output1_loss: 0.6953 - val_output2_loss: 0.6919 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00004: val_output3_loss did not improve from 0.54728
# Epoch 5/120
# 31/31 [==============================] - 8s 271ms/step - loss: 2.0426 - output3_loss: 0.6787 - output1_loss: 0.6816 - output2_loss: 0.6823 - output3_accuracy: 0.5938 - output1_accuracy: 0.5938 - output2_accuracy: 0.5938 - val_loss: 2.0831 - val_output3_loss: 0.6937 - val_output1_loss: 0.6950 - val_output2_loss: 0.6944 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00005: val_output3_loss did not improve from 0.54728
# Epoch 6/120
# 31/31 [==============================] - 9s 277ms/step - loss: 1.9920 - output3_loss: 0.6659 - output1_loss: 0.6639 - output2_loss: 0.6622 - output3_accuracy: 0.6367 - output1_accuracy: 0.6367 - output2_accuracy: 0.6367 - val_loss: 2.1023 - val_output3_loss: 0.6981 - val_output1_loss: 0.7036 - val_output2_loss: 0.7006 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00006: val_output3_loss did not improve from 0.54728
# Epoch 7/120
# 31/31 [==============================] - 8s 266ms/step - loss: 2.0812 - output3_loss: 0.6923 - output1_loss: 0.6955 - output2_loss: 0.6934 - output3_accuracy: 0.5508 - output1_accuracy: 0.5508 - output2_accuracy: 0.5508 - val_loss: 2.0706 - val_output3_loss: 0.6899 - val_output1_loss: 0.6905 - val_output2_loss: 0.6903 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00007: val_output3_loss did not improve from 0.54728
# Epoch 8/120
# 31/31 [==============================] - 8s 247ms/step - loss: 1.9587 - output3_loss: 0.6549 - output1_loss: 0.6517 - output2_loss: 0.6521 - output3_accuracy: 0.6758 - output1_accuracy: 0.6758 - output2_accuracy: 0.6758 - val_loss: 2.1733 - val_output3_loss: 0.7249 - val_output1_loss: 0.7206 - val_output2_loss: 0.7277 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00008: val_output3_loss did not improve from 0.54728
# Epoch 9/120
# 31/31 [==============================] - 9s 278ms/step - loss: 2.0100 - output3_loss: 0.6695 - output1_loss: 0.6693 - output2_loss: 0.6712 - output3_accuracy: 0.6250 - output1_accuracy: 0.6250 - output2_accuracy: 0.6250 - val_loss: 2.0968 - val_output3_loss: 0.6973 - val_output1_loss: 0.7020 - val_output2_loss: 0.6975 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00009: val_output3_loss did not improve from 0.54728
# Epoch 10/120
# 31/31 [==============================] - 8s 266ms/step - loss: 2.0092 - output3_loss: 0.6675 - output1_loss: 0.6699 - output2_loss: 0.6718 - output3_accuracy: 0.6172 - output1_accuracy: 0.6172 - output2_accuracy: 0.6172 - val_loss: 2.0819 - val_output3_loss: 0.6930 - val_output1_loss: 0.6949 - val_output2_loss: 0.6940 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00010: val_output3_loss did not improve from 0.54728
# Epoch 11/120
# 31/31 [==============================] - 8s 259ms/step - loss: 2.0015 - output3_loss: 0.6654 - output1_loss: 0.6675 - output2_loss: 0.6686 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 2.0799 - val_output3_loss: 0.6922 - val_output1_loss: 0.6944 - val_output2_loss: 0.6934 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00011: val_output3_loss did not improve from 0.54728
# Epoch 12/120
# 31/31 [==============================] - 9s 283ms/step - loss: 2.0186 - output3_loss: 0.6717 - output1_loss: 0.6769 - output2_loss: 0.6700 - output3_accuracy: 0.6016 - output1_accuracy: 0.6016 - output2_accuracy: 0.6016 - val_loss: 2.0796 - val_output3_loss: 0.6913 - val_output1_loss: 0.6943 - val_output2_loss: 0.6939 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00012: val_output3_loss did not improve from 0.54728
# Epoch 13/120
# 31/31 [==============================] - 8s 272ms/step - loss: 1.9743 - output3_loss: 0.6540 - output1_loss: 0.6621 - output2_loss: 0.6583 - output3_accuracy: 0.6289 - output1_accuracy: 0.6289 - output2_accuracy: 0.6289 - val_loss: 2.0808 - val_output3_loss: 0.6915 - val_output1_loss: 0.6956 - val_output2_loss: 0.6937 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00013: val_output3_loss did not improve from 0.54728
# Epoch 14/120
# 31/31 [==============================] - 9s 282ms/step - loss: 1.9480 - output3_loss: 0.6464 - output1_loss: 0.6513 - output2_loss: 0.6503 - output3_accuracy: 0.6523 - output1_accuracy: 0.6523 - output2_accuracy: 0.6523 - val_loss: 2.0972 - val_output3_loss: 0.6979 - val_output1_loss: 0.7015 - val_output2_loss: 0.6978 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00014: val_output3_loss did not improve from 0.54728
# Epoch 15/120
# 31/31 [==============================] - 8s 255ms/step - loss: 2.0141 - output3_loss: 0.6739 - output1_loss: 0.6706 - output2_loss: 0.6697 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 2.0818 - val_output3_loss: 0.6878 - val_output1_loss: 0.7001 - val_output2_loss: 0.6939 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00015: val_output3_loss did not improve from 0.54728
# Epoch 16/120
# 31/31 [==============================] - 8s 263ms/step - loss: 1.9276 - output3_loss: 0.6419 - output1_loss: 0.6443 - output2_loss: 0.6415 - output3_accuracy: 0.6641 - output1_accuracy: 0.6641 - output2_accuracy: 0.6641 - val_loss: 2.1137 - val_output3_loss: 0.6998 - val_output1_loss: 0.7092 - val_output2_loss: 0.7046 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00016: val_output3_loss did not improve from 0.54728
# Epoch 17/120
# 31/31 [==============================] - 9s 284ms/step - loss: 1.9584 - output3_loss: 0.6513 - output1_loss: 0.6527 - output2_loss: 0.6545 - output3_accuracy: 0.6367 - output1_accuracy: 0.6367 - output2_accuracy: 0.6367 - val_loss: 2.0945 - val_output3_loss: 0.6917 - val_output1_loss: 0.7035 - val_output2_loss: 0.6993 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00017: val_output3_loss did not improve from 0.54728
# Epoch 18/120
# 31/31 [==============================] - 8s 270ms/step - loss: 2.0343 - output3_loss: 0.6743 - output1_loss: 0.6796 - output2_loss: 0.6804 - output3_accuracy: 0.5898 - output1_accuracy: 0.5898 - output2_accuracy: 0.5898 - val_loss: 2.0715 - val_output3_loss: 0.6879 - val_output1_loss: 0.6940 - val_output2_loss: 0.6897 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00018: val_output3_loss did not improve from 0.54728
# Epoch 19/120
# 31/31 [==============================] - 8s 268ms/step - loss: 1.9863 - output3_loss: 0.6563 - output1_loss: 0.6683 - output2_loss: 0.6617 - output3_accuracy: 0.6064 - output1_accuracy: 0.6064 - output2_accuracy: 0.6064 - val_loss: 2.0735 - val_output3_loss: 0.6922 - val_output1_loss: 0.6920 - val_output2_loss: 0.6893 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00019: val_output3_loss did not improve from 0.54728
# Epoch 20/120
# 31/31 [==============================] - 9s 278ms/step - loss: 2.0551 - output3_loss: 0.6841 - output1_loss: 0.6876 - output2_loss: 0.6834 - output3_accuracy: 0.5586 - output1_accuracy: 0.5586 - output2_accuracy: 0.5586 - val_loss: 2.0352 - val_output3_loss: 0.6745 - val_output1_loss: 0.6838 - val_output2_loss: 0.6770 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00020: val_output3_loss did not improve from 0.54728
# Epoch 21/120
# 31/31 [==============================] - 9s 285ms/step - loss: 1.9957 - output3_loss: 0.6624 - output1_loss: 0.6687 - output2_loss: 0.6647 - output3_accuracy: 0.6055 - output1_accuracy: 0.6055 - output2_accuracy: 0.6055 - val_loss: 2.0389 - val_output3_loss: 0.6757 - val_output1_loss: 0.6864 - val_output2_loss: 0.6768 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00021: val_output3_loss did not improve from 0.54728
# Epoch 22/120
# 31/31 [==============================] - 8s 273ms/step - loss: 2.0543 - output3_loss: 0.6872 - output1_loss: 0.6831 - output2_loss: 0.6840 - output3_accuracy: 0.5703 - output1_accuracy: 0.5703 - output2_accuracy: 0.5703 - val_loss: 2.0372 - val_output3_loss: 0.6733 - val_output1_loss: 0.6862 - val_output2_loss: 0.6777 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00022: val_output3_loss did not improve from 0.54728
# Epoch 23/120
# 31/31 [==============================] - 8s 248ms/step - loss: 2.0384 - output3_loss: 0.6814 - output1_loss: 0.6807 - output2_loss: 0.6763 - output3_accuracy: 0.5742 - output1_accuracy: 0.5742 - output2_accuracy: 0.5742 - val_loss: 2.0376 - val_output3_loss: 0.6753 - val_output1_loss: 0.6858 - val_output2_loss: 0.6764 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00023: val_output3_loss did not improve from 0.54728
# Epoch 24/120
# 31/31 [==============================] - 9s 278ms/step - loss: 1.9802 - output3_loss: 0.6594 - output1_loss: 0.6634 - output2_loss: 0.6574 - output3_accuracy: 0.6265 - output1_accuracy: 0.6265 - output2_accuracy: 0.6265 - val_loss: 2.0362 - val_output3_loss: 0.6738 - val_output1_loss: 0.6870 - val_output2_loss: 0.6754 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00024: val_output3_loss did not improve from 0.54728
# Epoch 25/120
# 31/31 [==============================] - 8s 259ms/step - loss: 1.9462 - output3_loss: 0.6460 - output1_loss: 0.6526 - output2_loss: 0.6477 - output3_accuracy: 0.6426 - output1_accuracy: 0.6426 - output2_accuracy: 0.6426 - val_loss: 2.0431 - val_output3_loss: 0.6762 - val_output1_loss: 0.6914 - val_output2_loss: 0.6755 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00025: val_output3_loss did not improve from 0.54728
# Epoch 26/120
# 31/31 [==============================] - 8s 267ms/step - loss: 1.9617 - output3_loss: 0.6505 - output1_loss: 0.6584 - output2_loss: 0.6529 - output3_accuracy: 0.6367 - output1_accuracy: 0.6367 - output2_accuracy: 0.6367 - val_loss: 2.0491 - val_output3_loss: 0.6779 - val_output1_loss: 0.6928 - val_output2_loss: 0.6783 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00026: val_output3_loss did not improve from 0.54728
# Epoch 27/120
# 31/31 [==============================] - 8s 266ms/step - loss: 1.9840 - output3_loss: 0.6611 - output1_loss: 0.6629 - output2_loss: 0.6600 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 2.0320 - val_output3_loss: 0.6732 - val_output1_loss: 0.6884 - val_output2_loss: 0.6704 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00027: val_output3_loss did not improve from 0.54728
# Epoch 28/120
# 31/31 [==============================] - 9s 291ms/step - loss: 2.0072 - output3_loss: 0.6673 - output1_loss: 0.6717 - output2_loss: 0.6682 - output3_accuracy: 0.6016 - output1_accuracy: 0.6016 - output2_accuracy: 0.6016 - val_loss: 2.0290 - val_output3_loss: 0.6693 - val_output1_loss: 0.6894 - val_output2_loss: 0.6704 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00028: val_output3_loss did not improve from 0.54728
# Epoch 29/120
# 31/31 [==============================] - 8s 258ms/step - loss: 2.0544 - output3_loss: 0.6827 - output1_loss: 0.6881 - output2_loss: 0.6836 - output3_accuracy: 0.5508 - output1_accuracy: 0.5508 - output2_accuracy: 0.5508 - val_loss: 2.0208 - val_output3_loss: 0.6714 - val_output1_loss: 0.6816 - val_output2_loss: 0.6678 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00029: val_output3_loss did not improve from 0.54728
# Epoch 30/120
# 31/31 [==============================] - 9s 286ms/step - loss: 2.0131 - output3_loss: 0.6679 - output1_loss: 0.6772 - output2_loss: 0.6680 - output3_accuracy: 0.5820 - output1_accuracy: 0.5820 - output2_accuracy: 0.5820 - val_loss: 2.0146 - val_output3_loss: 0.6700 - val_output1_loss: 0.6794 - val_output2_loss: 0.6652 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00030: val_output3_loss did not improve from 0.54728
# Epoch 31/120
# 31/31 [==============================] - 8s 262ms/step - loss: 2.0075 - output3_loss: 0.6670 - output1_loss: 0.6742 - output2_loss: 0.6663 - output3_accuracy: 0.5820 - output1_accuracy: 0.5820 - output2_accuracy: 0.5820 - val_loss: 1.9989 - val_output3_loss: 0.6630 - val_output1_loss: 0.6783 - val_output2_loss: 0.6576 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00031: val_output3_loss did not improve from 0.54728
# Epoch 32/120
# 31/31 [==============================] - 8s 267ms/step - loss: 1.9942 - output3_loss: 0.6602 - output1_loss: 0.6699 - output2_loss: 0.6641 - output3_accuracy: 0.5820 - output1_accuracy: 0.5820 - output2_accuracy: 0.5820 - val_loss: 2.0044 - val_output3_loss: 0.6651 - val_output1_loss: 0.6805 - val_output2_loss: 0.6589 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00032: val_output3_loss did not improve from 0.54728
# Epoch 33/120
# 31/31 [==============================] - 8s 253ms/step - loss: 1.9550 - output3_loss: 0.6493 - output1_loss: 0.6563 - output2_loss: 0.6494 - output3_accuracy: 0.6211 - output1_accuracy: 0.6211 - output2_accuracy: 0.6211 - val_loss: 2.0094 - val_output3_loss: 0.6699 - val_output1_loss: 0.6795 - val_output2_loss: 0.6600 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00033: val_output3_loss did not improve from 0.54728
# Epoch 34/120
# 31/31 [==============================] - 9s 293ms/step - loss: 1.9450 - output3_loss: 0.6486 - output1_loss: 0.6539 - output2_loss: 0.6425 - output3_accuracy: 0.6406 - output1_accuracy: 0.6406 - output2_accuracy: 0.6406 - val_loss: 1.9969 - val_output3_loss: 0.6574 - val_output1_loss: 0.6821 - val_output2_loss: 0.6574 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00034: val_output3_loss did not improve from 0.54728
# Epoch 35/120
# 31/31 [==============================] - 9s 285ms/step - loss: 1.9711 - output3_loss: 0.6550 - output1_loss: 0.6650 - output2_loss: 0.6510 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 2.0129 - val_output3_loss: 0.6662 - val_output1_loss: 0.6827 - val_output2_loss: 0.6640 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00035: val_output3_loss did not improve from 0.54728
# Epoch 36/120
# 31/31 [==============================] - 9s 276ms/step - loss: 2.0256 - output3_loss: 0.6759 - output1_loss: 0.6775 - output2_loss: 0.6722 - output3_accuracy: 0.5977 - output1_accuracy: 0.5977 - output2_accuracy: 0.5977 - val_loss: 2.0117 - val_output3_loss: 0.6667 - val_output1_loss: 0.6806 - val_output2_loss: 0.6643 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00036: val_output3_loss did not improve from 0.54728
# Epoch 37/120
# 31/31 [==============================] - 9s 287ms/step - loss: 1.9054 - output3_loss: 0.6284 - output1_loss: 0.6471 - output2_loss: 0.6300 - output3_accuracy: 0.6523 - output1_accuracy: 0.6523 - output2_accuracy: 0.6523 - val_loss: 2.0387 - val_output3_loss: 0.6769 - val_output1_loss: 0.6902 - val_output2_loss: 0.6716 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00037: val_output3_loss did not improve from 0.54728
# Epoch 38/120
# 31/31 [==============================] - 8s 268ms/step - loss: 1.9987 - output3_loss: 0.6628 - output1_loss: 0.6708 - output2_loss: 0.6651 - output3_accuracy: 0.5742 - output1_accuracy: 0.5742 - output2_accuracy: 0.5742 - val_loss: 1.9883 - val_output3_loss: 0.6625 - val_output1_loss: 0.6734 - val_output2_loss: 0.6523 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00038: val_output3_loss did not improve from 0.54728
# Epoch 39/120
# 31/31 [==============================] - 9s 272ms/step - loss: 1.9422 - output3_loss: 0.6457 - output1_loss: 0.6491 - output2_loss: 0.6474 - output3_accuracy: 0.6386 - output1_accuracy: 0.6386 - output2_accuracy: 0.6386 - val_loss: 1.9905 - val_output3_loss: 0.6661 - val_output1_loss: 0.6751 - val_output2_loss: 0.6493 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00039: val_output3_loss did not improve from 0.54728
# Epoch 40/120
# 31/31 [==============================] - 8s 264ms/step - loss: 1.9627 - output3_loss: 0.6583 - output1_loss: 0.6559 - output2_loss: 0.6484 - output3_accuracy: 0.6289 - output1_accuracy: 0.6289 - output2_accuracy: 0.6289 - val_loss: 2.0035 - val_output3_loss: 0.6661 - val_output1_loss: 0.6827 - val_output2_loss: 0.6547 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00040: val_output3_loss did not improve from 0.54728
# Epoch 41/120
# 31/31 [==============================] - 8s 258ms/step - loss: 1.9666 - output3_loss: 0.6521 - output1_loss: 0.6649 - output2_loss: 0.6496 - output3_accuracy: 0.6055 - output1_accuracy: 0.6055 - output2_accuracy: 0.6055 - val_loss: 1.9926 - val_output3_loss: 0.6652 - val_output1_loss: 0.6770 - val_output2_loss: 0.6504 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00041: val_output3_loss did not improve from 0.54728
# Epoch 42/120
# 31/31 [==============================] - 8s 264ms/step - loss: 1.9258 - output3_loss: 0.6384 - output1_loss: 0.6505 - output2_loss: 0.6369 - output3_accuracy: 0.6172 - output1_accuracy: 0.6172 - output2_accuracy: 0.6211 - val_loss: 1.9681 - val_output3_loss: 0.6554 - val_output1_loss: 0.6749 - val_output2_loss: 0.6378 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00042: val_output3_loss did not improve from 0.54728
# Epoch 43/120
# 31/31 [==============================] - 9s 290ms/step - loss: 1.9284 - output3_loss: 0.6433 - output1_loss: 0.6463 - output2_loss: 0.6388 - output3_accuracy: 0.6445 - output1_accuracy: 0.6445 - output2_accuracy: 0.6484 - val_loss: 2.0271 - val_output3_loss: 0.6769 - val_output1_loss: 0.6892 - val_output2_loss: 0.6609 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00043: val_output3_loss did not improve from 0.54728
# Epoch 44/120
# 31/31 [==============================] - 9s 273ms/step - loss: 2.0003 - output3_loss: 0.6709 - output1_loss: 0.6683 - output2_loss: 0.6612 - output3_accuracy: 0.5820 - output1_accuracy: 0.5820 - output2_accuracy: 0.5859 - val_loss: 1.9544 - val_output3_loss: 0.6495 - val_output1_loss: 0.6660 - val_output2_loss: 0.6390 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5312
#
# Epoch 00044: val_output3_loss did not improve from 0.54728
# Epoch 45/120
# 31/31 [==============================] - 9s 275ms/step - loss: 1.9436 - output3_loss: 0.6532 - output1_loss: 0.6468 - output2_loss: 0.6436 - output3_accuracy: 0.6250 - output1_accuracy: 0.6250 - output2_accuracy: 0.6289 - val_loss: 1.9980 - val_output3_loss: 0.6668 - val_output1_loss: 0.6790 - val_output2_loss: 0.6523 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00045: val_output3_loss did not improve from 0.54728
# Epoch 46/120
# 31/31 [==============================] - 8s 262ms/step - loss: 2.0294 - output3_loss: 0.6753 - output1_loss: 0.6832 - output2_loss: 0.6709 - output3_accuracy: 0.5586 - output1_accuracy: 0.5625 - output2_accuracy: 0.5586 - val_loss: 1.9714 - val_output3_loss: 0.6592 - val_output1_loss: 0.6632 - val_output2_loss: 0.6489 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5469
#
# Epoch 00046: val_output3_loss did not improve from 0.54728
# Epoch 47/120
# 31/31 [==============================] - 8s 264ms/step - loss: 1.9822 - output3_loss: 0.6611 - output1_loss: 0.6637 - output2_loss: 0.6574 - output3_accuracy: 0.5859 - output1_accuracy: 0.5938 - output2_accuracy: 0.5820 - val_loss: 1.9806 - val_output3_loss: 0.6657 - val_output1_loss: 0.6658 - val_output2_loss: 0.6491 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5938
#
# Epoch 00047: val_output3_loss did not improve from 0.54728
# Epoch 48/120
# 31/31 [==============================] - 8s 271ms/step - loss: 1.9432 - output3_loss: 0.6429 - output1_loss: 0.6610 - output2_loss: 0.6393 - output3_accuracy: 0.5823 - output1_accuracy: 0.5863 - output2_accuracy: 0.5783 - val_loss: 1.9619 - val_output3_loss: 0.6577 - val_output1_loss: 0.6641 - val_output2_loss: 0.6401 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.6094
#
# Epoch 00048: val_output3_loss did not improve from 0.54728
# Epoch 49/120
# 31/31 [==============================] - 9s 304ms/step - loss: 1.9571 - output3_loss: 0.6544 - output1_loss: 0.6566 - output2_loss: 0.6460 - output3_accuracy: 0.6133 - output1_accuracy: 0.6172 - output2_accuracy: 0.6445 - val_loss: 1.9467 - val_output3_loss: 0.6478 - val_output1_loss: 0.6647 - val_output2_loss: 0.6342 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5625
#
# Epoch 00049: val_output3_loss did not improve from 0.54728
# Epoch 50/120
# 31/31 [==============================] - 8s 266ms/step - loss: 1.9223 - output3_loss: 0.6435 - output1_loss: 0.6445 - output2_loss: 0.6342 - output3_accuracy: 0.6024 - output1_accuracy: 0.6145 - output2_accuracy: 0.6265 - val_loss: 1.9510 - val_output3_loss: 0.6510 - val_output1_loss: 0.6668 - val_output2_loss: 0.6332 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5938
#
# Epoch 00050: val_output3_loss did not improve from 0.54728
# Epoch 51/120
# 31/31 [==============================] - 8s 264ms/step - loss: 1.8972 - output3_loss: 0.6218 - output1_loss: 0.6428 - output2_loss: 0.6326 - output3_accuracy: 0.6445 - output1_accuracy: 0.6445 - output2_accuracy: 0.6484 - val_loss: 1.9468 - val_output3_loss: 0.6391 - val_output1_loss: 0.6677 - val_output2_loss: 0.6400 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5312
#
# Epoch 00051: val_output3_loss did not improve from 0.54728
# Epoch 52/120
# 31/31 [==============================] - 8s 266ms/step - loss: 2.0027 - output3_loss: 0.6747 - output1_loss: 0.6716 - output2_loss: 0.6563 - output3_accuracy: 0.5742 - output1_accuracy: 0.5703 - output2_accuracy: 0.5898 - val_loss: 1.9298 - val_output3_loss: 0.6470 - val_output1_loss: 0.6591 - val_output2_loss: 0.6237 - val_output3_accuracy: 0.5625 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.7188
#
# Epoch 00052: val_output3_loss did not improve from 0.54728
# Epoch 53/120
# 31/31 [==============================] - 9s 274ms/step - loss: 1.9248 - output3_loss: 0.6404 - output1_loss: 0.6471 - output2_loss: 0.6373 - output3_accuracy: 0.6211 - output1_accuracy: 0.6133 - output2_accuracy: 0.6328 - val_loss: 1.8980 - val_output3_loss: 0.6313 - val_output1_loss: 0.6482 - val_output2_loss: 0.6185 - val_output3_accuracy: 0.5625 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5781
#
# Epoch 00053: val_output3_loss did not improve from 0.54728
# Epoch 54/120
# 31/31 [==============================] - 9s 268ms/step - loss: 1.9626 - output3_loss: 0.6542 - output1_loss: 0.6572 - output2_loss: 0.6512 - output3_accuracy: 0.6133 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 1.9402 - val_output3_loss: 0.6434 - val_output1_loss: 0.6587 - val_output2_loss: 0.6380 - val_output3_accuracy: 0.5312 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5625
#
# Epoch 00054: val_output3_loss did not improve from 0.54728
# Epoch 55/120
# 31/31 [==============================] - 9s 278ms/step - loss: 1.9588 - output3_loss: 0.6533 - output1_loss: 0.6587 - output2_loss: 0.6469 - output3_accuracy: 0.6133 - output1_accuracy: 0.5938 - output2_accuracy: 0.6211 - val_loss: 1.9197 - val_output3_loss: 0.6383 - val_output1_loss: 0.6590 - val_output2_loss: 0.6224 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.6562
#
# Epoch 00055: val_output3_loss did not improve from 0.54728
# Epoch 56/120
# 31/31 [==============================] - 8s 265ms/step - loss: 1.9528 - output3_loss: 0.6526 - output1_loss: 0.6510 - output2_loss: 0.6492 - output3_accuracy: 0.6172 - output1_accuracy: 0.6250 - output2_accuracy: 0.6367 - val_loss: 1.9159 - val_output3_loss: 0.6379 - val_output1_loss: 0.6535 - val_output2_loss: 0.6244 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5625
#
# Epoch 00056: val_output3_loss did not improve from 0.54728
# Epoch 57/120
# 31/31 [==============================] - 8s 248ms/step - loss: 1.9954 - output3_loss: 0.6716 - output1_loss: 0.6659 - output2_loss: 0.6579 - output3_accuracy: 0.6016 - output1_accuracy: 0.6055 - output2_accuracy: 0.6289 - val_loss: 1.8908 - val_output3_loss: 0.6354 - val_output1_loss: 0.6387 - val_output2_loss: 0.6167 - val_output3_accuracy: 0.5625 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.6250
#
# Epoch 00057: val_output3_loss did not improve from 0.54728
# Epoch 58/120
# 31/31 [==============================] - 8s 268ms/step - loss: 1.8781 - output3_loss: 0.6243 - output1_loss: 0.6334 - output2_loss: 0.6204 - output3_accuracy: 0.6406 - output1_accuracy: 0.6367 - output2_accuracy: 0.6562 - val_loss: 1.8661 - val_output3_loss: 0.6245 - val_output1_loss: 0.6409 - val_output2_loss: 0.6007 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.6250
#
# Epoch 00058: val_output3_loss did not improve from 0.54728
# Epoch 59/120
# 31/31 [==============================] - 8s 263ms/step - loss: 1.8479 - output3_loss: 0.6190 - output1_loss: 0.6273 - output2_loss: 0.6016 - output3_accuracy: 0.6602 - output1_accuracy: 0.6445 - output2_accuracy: 0.6719 - val_loss: 1.8625 - val_output3_loss: 0.6216 - val_output1_loss: 0.6408 - val_output2_loss: 0.6002 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.6094
#
# Epoch 00059: val_output3_loss did not improve from 0.54728
# Epoch 60/120
# 31/31 [==============================] - 7s 238ms/step - loss: 1.9142 - output3_loss: 0.6442 - output1_loss: 0.6397 - output2_loss: 0.6303 - output3_accuracy: 0.6250 - output1_accuracy: 0.6445 - output2_accuracy: 0.6367 - val_loss: 1.9265 - val_output3_loss: 0.6374 - val_output1_loss: 0.6642 - val_output2_loss: 0.6250 - val_output3_accuracy: 0.5469 - val_output1_accuracy: 0.5469 - val_output2_accuracy: 0.5781
#
# Epoch 00060: val_output3_loss did not improve from 0.54728
# Epoch 61/120
# 31/31 [==============================] - 9s 274ms/step - loss: 1.9598 - output3_loss: 0.6509 - output1_loss: 0.6591 - output2_loss: 0.6499 - output3_accuracy: 0.5781 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 1.8417 - val_output3_loss: 0.6161 - val_output1_loss: 0.6340 - val_output2_loss: 0.5917 - val_output3_accuracy: 0.6250 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6875
#
# Epoch 00061: val_output3_loss did not improve from 0.54728
# Epoch 62/120
# 31/31 [==============================] - 8s 255ms/step - loss: 1.9122 - output3_loss: 0.6401 - output1_loss: 0.6397 - output2_loss: 0.6325 - output3_accuracy: 0.6305 - output1_accuracy: 0.6546 - output2_accuracy: 0.6426 - val_loss: 1.8681 - val_output3_loss: 0.6229 - val_output1_loss: 0.6456 - val_output2_loss: 0.5996 - val_output3_accuracy: 0.5625 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6250
#
# Epoch 00062: val_output3_loss did not improve from 0.54728
# Epoch 63/120
# 31/31 [==============================] - 8s 262ms/step - loss: 1.8667 - output3_loss: 0.6231 - output1_loss: 0.6307 - output2_loss: 0.6129 - output3_accuracy: 0.6094 - output1_accuracy: 0.6094 - output2_accuracy: 0.6484 - val_loss: 1.8357 - val_output3_loss: 0.6110 - val_output1_loss: 0.6319 - val_output2_loss: 0.5929 - val_output3_accuracy: 0.5938 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6250
#
# Epoch 00063: val_output3_loss did not improve from 0.54728
# Epoch 64/120
# 31/31 [==============================] - 8s 257ms/step - loss: 1.9899 - output3_loss: 0.6607 - output1_loss: 0.6698 - output2_loss: 0.6595 - output3_accuracy: 0.5898 - output1_accuracy: 0.6094 - output2_accuracy: 0.6094 - val_loss: 1.8664 - val_output3_loss: 0.6235 - val_output1_loss: 0.6349 - val_output2_loss: 0.6080 - val_output3_accuracy: 0.6875 - val_output1_accuracy: 0.6719 - val_output2_accuracy: 0.7031
#
# Epoch 00064: val_output3_loss did not improve from 0.54728
# Epoch 65/120
# 31/31 [==============================] - 9s 276ms/step - loss: 1.9028 - output3_loss: 0.6345 - output1_loss: 0.6377 - output2_loss: 0.6306 - output3_accuracy: 0.6641 - output1_accuracy: 0.6406 - output2_accuracy: 0.6523 - val_loss: 1.8634 - val_output3_loss: 0.6199 - val_output1_loss: 0.6429 - val_output2_loss: 0.6006 - val_output3_accuracy: 0.6250 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.7031
#
# Epoch 00065: val_output3_loss did not improve from 0.54728
# Epoch 66/120
# 31/31 [==============================] - 8s 260ms/step - loss: 1.9246 - output3_loss: 0.6416 - output1_loss: 0.6536 - output2_loss: 0.6294 - output3_accuracy: 0.6172 - output1_accuracy: 0.6172 - output2_accuracy: 0.6133 - val_loss: 1.8261 - val_output3_loss: 0.6048 - val_output1_loss: 0.6309 - val_output2_loss: 0.5904 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.5938
#
# Epoch 00066: val_output3_loss did not improve from 0.54728
# Epoch 67/120
# 31/31 [==============================] - 9s 292ms/step - loss: 1.8513 - output3_loss: 0.6112 - output1_loss: 0.6324 - output2_loss: 0.6076 - output3_accuracy: 0.6992 - output1_accuracy: 0.6328 - output2_accuracy: 0.7070 - val_loss: 1.8671 - val_output3_loss: 0.6265 - val_output1_loss: 0.6472 - val_output2_loss: 0.5933 - val_output3_accuracy: 0.5781 - val_output1_accuracy: 0.5625 - val_output2_accuracy: 0.6406
#
# Epoch 00067: val_output3_loss did not improve from 0.54728
# Epoch 68/120
# 31/31 [==============================] - 8s 270ms/step - loss: 1.9549 - output3_loss: 0.6536 - output1_loss: 0.6518 - output2_loss: 0.6495 - output3_accuracy: 0.6367 - output1_accuracy: 0.6094 - output2_accuracy: 0.6484 - val_loss: 1.8059 - val_output3_loss: 0.5928 - val_output1_loss: 0.6349 - val_output2_loss: 0.5782 - val_output3_accuracy: 0.6562 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.6875
#
# Epoch 00068: val_output3_loss did not improve from 0.54728
# Epoch 69/120
# 31/31 [==============================] - 8s 274ms/step - loss: 1.8332 - output3_loss: 0.6050 - output1_loss: 0.6260 - output2_loss: 0.6022 - output3_accuracy: 0.6758 - output1_accuracy: 0.6562 - output2_accuracy: 0.6680 - val_loss: 1.7961 - val_output3_loss: 0.5923 - val_output1_loss: 0.6249 - val_output2_loss: 0.5790 - val_output3_accuracy: 0.5781 - val_output1_accuracy: 0.5938 - val_output2_accuracy: 0.6406
#
# Epoch 00069: val_output3_loss did not improve from 0.54728
# Epoch 70/120
# 31/31 [==============================] - 8s 254ms/step - loss: 1.9490 - output3_loss: 0.6522 - output1_loss: 0.6577 - output2_loss: 0.6391 - output3_accuracy: 0.6133 - output1_accuracy: 0.6289 - output2_accuracy: 0.6289 - val_loss: 1.8644 - val_output3_loss: 0.6208 - val_output1_loss: 0.6359 - val_output2_loss: 0.6076 - val_output3_accuracy: 0.6719 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6719
#
# Epoch 00070: val_output3_loss did not improve from 0.54728
# Epoch 71/120
# 31/31 [==============================] - 9s 283ms/step - loss: 1.8974 - output3_loss: 0.6296 - output1_loss: 0.6430 - output2_loss: 0.6249 - output3_accuracy: 0.6562 - output1_accuracy: 0.6484 - output2_accuracy: 0.6602 - val_loss: 1.8086 - val_output3_loss: 0.6014 - val_output1_loss: 0.6276 - val_output2_loss: 0.5796 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6719
#
# Epoch 00071: val_output3_loss did not improve from 0.54728
# Epoch 72/120
# 31/31 [==============================] - 9s 289ms/step - loss: 1.8035 - output3_loss: 0.5971 - output1_loss: 0.6116 - output2_loss: 0.5948 - output3_accuracy: 0.6797 - output1_accuracy: 0.6641 - output2_accuracy: 0.6875 - val_loss: 1.7948 - val_output3_loss: 0.5935 - val_output1_loss: 0.6221 - val_output2_loss: 0.5793 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6250
#
# Epoch 00072: val_output3_loss did not improve from 0.54728
# Epoch 73/120
# 31/31 [==============================] - 8s 272ms/step - loss: 1.8925 - output3_loss: 0.6303 - output1_loss: 0.6428 - output2_loss: 0.6195 - output3_accuracy: 0.6445 - output1_accuracy: 0.6289 - output2_accuracy: 0.6680 - val_loss: 1.7356 - val_output3_loss: 0.5658 - val_output1_loss: 0.6151 - val_output2_loss: 0.5548 - val_output3_accuracy: 0.7969 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.7031
#
# Epoch 00073: val_output3_loss did not improve from 0.54728
# Epoch 74/120
# 31/31 [==============================] - 9s 283ms/step - loss: 1.9993 - output3_loss: 0.6660 - output1_loss: 0.6683 - output2_loss: 0.6650 - output3_accuracy: 0.5703 - output1_accuracy: 0.5781 - output2_accuracy: 0.6016 - val_loss: 1.7877 - val_output3_loss: 0.5889 - val_output1_loss: 0.6235 - val_output2_loss: 0.5753 - val_output3_accuracy: 0.7188 - val_output1_accuracy: 0.7031 - val_output2_accuracy: 0.7500
#
# Epoch 00074: val_output3_loss did not improve from 0.54728
# Epoch 75/120
# 31/31 [==============================] - 8s 274ms/step - loss: 1.8746 - output3_loss: 0.6196 - output1_loss: 0.6392 - output2_loss: 0.6158 - output3_accuracy: 0.6641 - output1_accuracy: 0.6602 - output2_accuracy: 0.6523 - val_loss: 1.7260 - val_output3_loss: 0.5669 - val_output1_loss: 0.6073 - val_output2_loss: 0.5518 - val_output3_accuracy: 0.6406 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.7031
#
# Epoch 00075: val_output3_loss did not improve from 0.54728
# Epoch 76/120
# 31/31 [==============================] - 8s 277ms/step - loss: 1.8337 - output3_loss: 0.6107 - output1_loss: 0.6218 - output2_loss: 0.6012 - output3_accuracy: 0.6426 - output1_accuracy: 0.6506 - output2_accuracy: 0.6667 - val_loss: 1.7309 - val_output3_loss: 0.5669 - val_output1_loss: 0.6108 - val_output2_loss: 0.5532 - val_output3_accuracy: 0.6250 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.7031
#
# Epoch 00076: val_output3_loss did not improve from 0.54728
# Epoch 77/120
# 31/31 [==============================] - 9s 284ms/step - loss: 1.8225 - output3_loss: 0.6154 - output1_loss: 0.6089 - output2_loss: 0.5983 - output3_accuracy: 0.6406 - output1_accuracy: 0.6680 - output2_accuracy: 0.6602 - val_loss: 1.7528 - val_output3_loss: 0.5580 - val_output1_loss: 0.6356 - val_output2_loss: 0.5592 - val_output3_accuracy: 0.6562 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6875
#
# Epoch 00077: val_output3_loss did not improve from 0.54728
# Epoch 78/120
# 31/31 [==============================] - 8s 254ms/step - loss: 1.8586 - output3_loss: 0.6150 - output1_loss: 0.6325 - output2_loss: 0.6110 - output3_accuracy: 0.6562 - output1_accuracy: 0.6562 - output2_accuracy: 0.6602 - val_loss: 1.7243 - val_output3_loss: 0.5631 - val_output1_loss: 0.6085 - val_output2_loss: 0.5527 - val_output3_accuracy: 0.7031 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.7031
#
# Epoch 00078: val_output3_loss did not improve from 0.54728
# Epoch 79/120
# 31/31 [==============================] - 9s 276ms/step - loss: 1.9161 - output3_loss: 0.6471 - output1_loss: 0.6342 - output2_loss: 0.6348 - output3_accuracy: 0.6250 - output1_accuracy: 0.6484 - output2_accuracy: 0.6445 - val_loss: 1.7323 - val_output3_loss: 0.5686 - val_output1_loss: 0.6044 - val_output2_loss: 0.5593 - val_output3_accuracy: 0.6875 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.7031
#
# Epoch 00079: val_output3_loss did not improve from 0.54728
# Epoch 80/120
# 31/31 [==============================] - 8s 265ms/step - loss: 1.7666 - output3_loss: 0.5813 - output1_loss: 0.6089 - output2_loss: 0.5764 - output3_accuracy: 0.6914 - output1_accuracy: 0.6836 - output2_accuracy: 0.7148 - val_loss: 1.8614 - val_output3_loss: 0.6373 - val_output1_loss: 0.6330 - val_output2_loss: 0.5911 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6406
#
# Epoch 00080: val_output3_loss did not improve from 0.54728
# Epoch 81/120
# 31/31 [==============================] - 9s 302ms/step - loss: 1.7963 - output3_loss: 0.5935 - output1_loss: 0.6102 - output2_loss: 0.5925 - output3_accuracy: 0.6627 - output1_accuracy: 0.6506 - output2_accuracy: 0.6747 - val_loss: 1.8390 - val_output3_loss: 0.6198 - val_output1_loss: 0.6236 - val_output2_loss: 0.5957 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.5938
#
# Epoch 00081: val_output3_loss did not improve from 0.54728
# Epoch 82/120
# 31/31 [==============================] - 8s 247ms/step - loss: 1.8844 - output3_loss: 0.6194 - output1_loss: 0.6431 - output2_loss: 0.6220 - output3_accuracy: 0.6953 - output1_accuracy: 0.6680 - output2_accuracy: 0.6797 - val_loss: 1.7011 - val_output3_loss: 0.5524 - val_output1_loss: 0.6053 - val_output2_loss: 0.5434 - val_output3_accuracy: 0.7031 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.7188
#
# Epoch 00082: val_output3_loss did not improve from 0.54728
# Epoch 83/120
# 31/31 [==============================] - 8s 272ms/step - loss: 1.8757 - output3_loss: 0.6249 - output1_loss: 0.6323 - output2_loss: 0.6185 - output3_accuracy: 0.6367 - output1_accuracy: 0.6406 - output2_accuracy: 0.6523 - val_loss: 1.7167 - val_output3_loss: 0.5642 - val_output1_loss: 0.5982 - val_output2_loss: 0.5543 - val_output3_accuracy: 0.6875 - val_output1_accuracy: 0.6562 - val_output2_accuracy: 0.7344
#
# Epoch 00083: val_output3_loss did not improve from 0.54728
# Epoch 84/120
# 31/31 [==============================] - 8s 247ms/step - loss: 1.8060 - output3_loss: 0.5994 - output1_loss: 0.6080 - output2_loss: 0.5986 - output3_accuracy: 0.6914 - output1_accuracy: 0.6875 - output2_accuracy: 0.7070 - val_loss: 1.8322 - val_output3_loss: 0.6162 - val_output1_loss: 0.6171 - val_output2_loss: 0.5988 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6406
#
# Epoch 00084: val_output3_loss did not improve from 0.54728
# Epoch 85/120
# 31/31 [==============================] - 8s 254ms/step - loss: 1.8335 - output3_loss: 0.6009 - output1_loss: 0.6236 - output2_loss: 0.6091 - output3_accuracy: 0.6953 - output1_accuracy: 0.6758 - output2_accuracy: 0.6680 - val_loss: 1.6669 - val_output3_loss: 0.5335 - val_output1_loss: 0.6033 - val_output2_loss: 0.5301 - val_output3_accuracy: 0.6875 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.7031
#
# Epoch 00085: val_output3_loss improved from 0.54728 to 0.53348, saving model to GoogLeNet_Weights.h5
# Epoch 86/120
# 31/31 [==============================] - 8s 269ms/step - loss: 1.8560 - output3_loss: 0.6173 - output1_loss: 0.6261 - output2_loss: 0.6126 - output3_accuracy: 0.6211 - output1_accuracy: 0.6523 - output2_accuracy: 0.6445 - val_loss: 1.7312 - val_output3_loss: 0.5652 - val_output1_loss: 0.6086 - val_output2_loss: 0.5574 - val_output3_accuracy: 0.6406 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.6875
#
# Epoch 00086: val_output3_loss did not improve from 0.53348
# Epoch 87/120
# 31/31 [==============================] - 9s 296ms/step - loss: 1.8635 - output3_loss: 0.6161 - output1_loss: 0.6346 - output2_loss: 0.6128 - output3_accuracy: 0.6680 - output1_accuracy: 0.6523 - output2_accuracy: 0.6641 - val_loss: 1.7631 - val_output3_loss: 0.5864 - val_output1_loss: 0.6028 - val_output2_loss: 0.5739 - val_output3_accuracy: 0.5938 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6250
#
# Epoch 00087: val_output3_loss did not improve from 0.53348
# Epoch 88/120
# 31/31 [==============================] - 9s 296ms/step - loss: 1.8423 - output3_loss: 0.6076 - output1_loss: 0.6214 - output2_loss: 0.6132 - output3_accuracy: 0.6602 - output1_accuracy: 0.6523 - output2_accuracy: 0.6484 - val_loss: 1.7473 - val_output3_loss: 0.5731 - val_output1_loss: 0.6115 - val_output2_loss: 0.5627 - val_output3_accuracy: 0.7031 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.6875
#
# Epoch 00088: val_output3_loss did not improve from 0.53348
# Epoch 89/120
# 31/31 [==============================] - 9s 288ms/step - loss: 1.8691 - output3_loss: 0.6212 - output1_loss: 0.6335 - output2_loss: 0.6144 - output3_accuracy: 0.6367 - output1_accuracy: 0.6484 - output2_accuracy: 0.6523 - val_loss: 1.6560 - val_output3_loss: 0.5294 - val_output1_loss: 0.6008 - val_output2_loss: 0.5258 - val_output3_accuracy: 0.7344 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.7344
#
# Epoch 00089: val_output3_loss improved from 0.53348 to 0.52935, saving model to GoogLeNet_Weights.h5
# Epoch 90/120
# 31/31 [==============================] - 8s 266ms/step - loss: 1.8596 - output3_loss: 0.6163 - output1_loss: 0.6334 - output2_loss: 0.6100 - output3_accuracy: 0.6719 - output1_accuracy: 0.6367 - output2_accuracy: 0.6836 - val_loss: 1.7153 - val_output3_loss: 0.5669 - val_output1_loss: 0.5943 - val_output2_loss: 0.5541 - val_output3_accuracy: 0.6562 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.6875
#
# Epoch 00090: val_output3_loss did not improve from 0.52935
# Epoch 91/120
# 31/31 [==============================] - 8s 250ms/step - loss: 1.8825 - output3_loss: 0.6230 - output1_loss: 0.6340 - output2_loss: 0.6255 - output3_accuracy: 0.6523 - output1_accuracy: 0.6562 - output2_accuracy: 0.6406 - val_loss: 1.7190 - val_output3_loss: 0.5683 - val_output1_loss: 0.5962 - val_output2_loss: 0.5544 - val_output3_accuracy: 0.6406 - val_output1_accuracy: 0.7031 - val_output2_accuracy: 0.6719
#
# Epoch 00091: val_output3_loss did not improve from 0.52935
# Epoch 92/120
# 31/31 [==============================] - 8s 274ms/step - loss: 1.8380 - output3_loss: 0.6069 - output1_loss: 0.6326 - output2_loss: 0.5985 - output3_accuracy: 0.6719 - output1_accuracy: 0.6445 - output2_accuracy: 0.6484 - val_loss: 1.7016 - val_output3_loss: 0.5556 - val_output1_loss: 0.5988 - val_output2_loss: 0.5472 - val_output3_accuracy: 0.6719 - val_output1_accuracy: 0.6250 - val_output2_accuracy: 0.6875
#
# Epoch 00092: val_output3_loss did not improve from 0.52935
# Epoch 93/120
# 31/31 [==============================] - 8s 252ms/step - loss: 1.7402 - output3_loss: 0.5818 - output1_loss: 0.5884 - output2_loss: 0.5700 - output3_accuracy: 0.6562 - output1_accuracy: 0.6914 - output2_accuracy: 0.6641 - val_loss: 1.8253 - val_output3_loss: 0.6195 - val_output1_loss: 0.6171 - val_output2_loss: 0.5887 - val_output3_accuracy: 0.6562 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6406
#
# Epoch 00093: val_output3_loss did not improve from 0.52935
# Epoch 94/120
# 31/31 [==============================] - 9s 284ms/step - loss: 1.7826 - output3_loss: 0.5855 - output1_loss: 0.6127 - output2_loss: 0.5844 - output3_accuracy: 0.6836 - output1_accuracy: 0.6484 - output2_accuracy: 0.6602 - val_loss: 1.6917 - val_output3_loss: 0.5533 - val_output1_loss: 0.5928 - val_output2_loss: 0.5456 - val_output3_accuracy: 0.7188 - val_output1_accuracy: 0.7031 - val_output2_accuracy: 0.7188
#
# Epoch 00094: val_output3_loss did not improve from 0.52935
# Epoch 95/120
# 31/31 [==============================] - 8s 269ms/step - loss: 1.7102 - output3_loss: 0.5640 - output1_loss: 0.5870 - output2_loss: 0.5591 - output3_accuracy: 0.6914 - output1_accuracy: 0.6758 - output2_accuracy: 0.7188 - val_loss: 1.7927 - val_output3_loss: 0.6091 - val_output1_loss: 0.6122 - val_output2_loss: 0.5714 - val_output3_accuracy: 0.6562 - val_output1_accuracy: 0.5781 - val_output2_accuracy: 0.6875
#
# Epoch 00095: val_output3_loss did not improve from 0.52935
# Epoch 96/120
# 31/31 [==============================] - 8s 253ms/step - loss: 1.8266 - output3_loss: 0.6194 - output1_loss: 0.6106 - output2_loss: 0.5966 - output3_accuracy: 0.6211 - output1_accuracy: 0.6680 - output2_accuracy: 0.6797 - val_loss: 1.7536 - val_output3_loss: 0.5964 - val_output1_loss: 0.5929 - val_output2_loss: 0.5643 - val_output3_accuracy: 0.6094 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.6406
#
# Epoch 00096: val_output3_loss did not improve from 0.52935
# Epoch 97/120
# 31/31 [==============================] - 8s 260ms/step - loss: 1.9465 - output3_loss: 0.6543 - output1_loss: 0.6506 - output2_loss: 0.6416 - output3_accuracy: 0.6328 - output1_accuracy: 0.6250 - output2_accuracy: 0.6484 - val_loss: 1.7484 - val_output3_loss: 0.5842 - val_output1_loss: 0.5947 - val_output2_loss: 0.5694 - val_output3_accuracy: 0.7344 - val_output1_accuracy: 0.6562 - val_output2_accuracy: 0.7344
#
# Epoch 00097: val_output3_loss did not improve from 0.52935
# Epoch 98/120
# 31/31 [==============================] - 8s 276ms/step - loss: 1.8305 - output3_loss: 0.6036 - output1_loss: 0.6246 - output2_loss: 0.6024 - output3_accuracy: 0.6719 - output1_accuracy: 0.6797 - output2_accuracy: 0.6836 - val_loss: 1.7008 - val_output3_loss: 0.5651 - val_output1_loss: 0.5874 - val_output2_loss: 0.5484 - val_output3_accuracy: 0.6406 - val_output1_accuracy: 0.6094 - val_output2_accuracy: 0.6406
#
# Epoch 00098: val_output3_loss did not improve from 0.52935
# Epoch 99/120
# 31/31 [==============================] - 8s 252ms/step - loss: 1.8047 - output3_loss: 0.5963 - output1_loss: 0.6148 - output2_loss: 0.5936 - output3_accuracy: 0.6875 - output1_accuracy: 0.6602 - output2_accuracy: 0.6914 - val_loss: 1.7722 - val_output3_loss: 0.6057 - val_output1_loss: 0.5901 - val_output2_loss: 0.5763 - val_output3_accuracy: 0.6250 - val_output1_accuracy: 0.6406 - val_output2_accuracy: 0.6250
#
# Epoch 00099: val_output3_loss did not improve from 0.52935
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
#
#
# ---------------------------------------------
# GoogLeNet  Model
# Total Epochs : 99
# Restoring best Weights
# ---------------------------------------------
# Best Epoch : 88
# ---------------------------------------------
# Accuracy on train: 0.63671875 	Loss on train: 0.6212406754493713
# Accuracy on val: 0.734375 	Loss on val: 0.5293539762496948
# ---------------------------------------------

# %% [markdown]
# ## **Model Evaluation on the TestSet**

# %%
# %matplotlib inline
def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve, accuracy_score, classification_report, confusion_matrix

def test_set_results(pred_value, n=1):    
    y_test = test_generator.labels
    X_test, _ = test_generator.next()
    
    corr_pred = metrics.confusion_matrix(y_test, pred_value)
    fig=plt.figure(figsize=(10, 8))
    ax = plt.axes()
    
    sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Purples", xticklabels=CATEGORIES, yticklabels=CATEGORIES)
    ax.set_title('Dense Output {}'.format(n))
    plt.show()
    
    n_correct = np.int(corr_pred[0][0] + corr_pred[1][1]) # + corr_pred[2][2]
    print('...'*15)

    print('> Correct Predictions:', n_correct)
    
    n_wrongs = len(y_test) - n_correct
    print('> Wrong Predictions:', n_wrongs)
    print('...'*15)
    
    print(classification_report(test_generator.labels, pred_value, target_names=CATEGORIES))

# %%
def printResults(name, model):
    predictions = model.predict(test_generator, verbose=1)
    preds = np.argmax(predictions, axis=1)
    test_set_results(preds)

# %%
def model_summary(model, history, name):
    index = (len(history.history[getMetrics(name, 'loss')]) - (patience + 1))
    print('Best Epochs: ', index)
    
    if name == 'GoogLeNet':
        results = model.evaluate(test_generator, verbose=1)
        loss, output3_loss, output1_loss, output2_loss, output3_accuracy, output1_accuracy, output2_accuracy = results
        
        for i in range(3):
            n = i + 1
            out_layer = 'Output Layer {}'.format(n)
            
            if n == 1:
                test_accuracy = output1_accuracy
                test_loss = output1_loss

            if n == 2:
                test_accuracy = output2_accuracy
                test_loss = output2_loss
                
            if n == 3:
                test_accuracy = output3_accuracy
                test_loss = output3_loss
                
                
            output_name = 'output{}_'.format(n)
            train_accuracy, train_loss = history.history[output_name + 'accuracy'][index], history.history[output_name + 'loss'][index]
            
  
            print_graph(output_name + 'loss', index, history)
            print_graph(output_name + 'accuracy', index, history)
        
            print('---'*15)  
            print('GoogLeNet Dense output {}:'.format(n))
            
            print('> Accuracy on train :'.format(out_layer), train_accuracy, 
                  '\tLoss on train:',train_loss)
        
            print('> Accuracy on test :'.format(out_layer), test_accuracy,
                  '\tLoss on test:',test_loss)
            
            print('---'*15)
            print('> predicting test')
            print('---'*15)
            
            predictions = model.predict(test_generator, verbose=1)
            preds = np.argmax(predictions[i], axis=1)
            test_set_results(preds, n)
                
    else:
        test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
        
        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        
        print('---'*15) 
        print(name)
        print('> Accuracy on train:',train_accuracy, 
              '\tLoss on train:',train_loss)
        
        print('> Accuracy on test:',test_accuracy,
              '\tLoss on test:',test_loss)
        
        print('---'*15)
        print('> predicting test')
        print('---'*15)
        
        printResults(name, model)

# %% [markdown]
# ## **GoogLeNet Results**

# %%
model_summary(g_model, g_history, 'GoogLeNet')
# Out:
# Best Epochs:  88
# 19/19 [==============================] - 12s 616ms/step - loss: 1.8407 - output3_loss: 0.6194 - output1_loss: 0.6079 - output2_loss: 0.6134 - output3_accuracy: 0.6600 - output1_accuracy: 0.6800 - output2_accuracy: 0.6733
# ---------------------------------------------
# GoogLeNet Dense output 1:
# > Accuracy on train : 0.6484375 	Loss on train: 0.6334587335586548
# > Accuracy on test : 0.6800000071525574 	Loss on test: 0.607947587966919
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 19/19 [==============================] - 12s 615ms/step
# .............................................
# > Correct Predictions: 99
# > Wrong Predictions: 51
# .............................................
#               precision    recall  f1-score   support
#
#       level1       0.51      0.50      0.50        52
#       level2       0.74      0.74      0.74        98
#
#     accuracy                           0.66       150
#    macro avg       0.62      0.62      0.62       150
# weighted avg       0.66      0.66      0.66       150
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_5084/3032867848.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1]) # + corr_pred[2][2]
# ---------------------------------------------
# GoogLeNet Dense output 2:
# > Accuracy on train : 0.65234375 	Loss on train: 0.6143836975097656
# > Accuracy on test : 0.6733333468437195 	Loss on test: 0.6133685111999512
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 19/19 [==============================] - 12s 621ms/step
# .............................................
# > Correct Predictions: 102
# > Wrong Predictions: 48
# .............................................
#               precision    recall  f1-score   support
#
#       level1       0.62      0.19      0.29        52
#       level2       0.69      0.94      0.79        98
#
#     accuracy                           0.68       150
#    macro avg       0.66      0.57      0.54       150
# weighted avg       0.67      0.68      0.62       150
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_5084/3032867848.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1]) # + corr_pred[2][2]
# ---------------------------------------------
# GoogLeNet Dense output 3:
# > Accuracy on train : 0.63671875 	Loss on train: 0.6212406754493713
# > Accuracy on test : 0.6600000262260437 	Loss on test: 0.6194168925285339
# ---------------------------------------------
# > predicting test
# ---------------------------------------------
# 19/19 [==============================] - 12s 612ms/step
# .............................................
# > Correct Predictions: 95
# > Wrong Predictions: 55
# .............................................
#               precision    recall  f1-score   support
#
#       level1       0.46      0.33      0.38        52
#       level2       0.69      0.80      0.74        98
#
#     accuracy                           0.63       150
#    macro avg       0.57      0.56      0.56       150
# weighted avg       0.61      0.63      0.62       150
# C:\Users\MCSP_Lab\AppData\Local\Temp/ipykernel_5084/3032867848.py:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int(corr_pred[0][0] + corr_pred[1][1]) # + corr_pred[2][2]
